# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from linearmodels import PanelOLS
from sklearn.decomposition import PCA

# %%
#read in most recent final product
df = pd.read_csv('/home/twalton_umass_edu/Political Polarization Project/final/final_product_topic_45_20210427.csv')

#list of schools to loop through
schools = ['s1', 's2', 's3', 's4', 's5', 's6', 's8']

#only want republicans
df = df[df['dem_org'] == 1]

#number of data points
print('total original data points: ' + str(len(df)))
      
#get rid of first three period due to missing ties
df = df[(df['period'] >= 4)]

df = df.groupby(['user_id', 'school']).filter(lambda x: len(x) > 25)
    
#fill in nans with 0
df = df.fillna(0)
      
#create new variable that is the variance of the rep count for each user_id/school pair
df = df.join(df.groupby(['user_id', 'school'])['rep_count'].var(), on = ['user_id', 'school'], rsuffix = '_var')

#create new variable that is the variance of the dem_coutn for each user_id/school pair
df = df.join(df.groupby(['user_id', 'school'])['dem_count'].var(), on = ['user_id', 'school'], rsuffix = '_var')

#create a new variable that is the total number of tweets for the individual
df = df.join(df.groupby(['user_id', 'school'])['num_tweets'].sum(), on = ['user_id', 'school'], rsuffix = '_sum')

#keep usee that have at least both variance or at least one tweet
df = df[(df['num_tweets_sum'] != 0) | ((df['dem_count_var'] != 0) & (df['rep_count_var'] != 0))]

      
topics = {"X0": "education", "X1": "names", "X2": "punish_law", "X3": "racism",
                       "X4": "covid", "X5": "event", "X6": "trump", "X7": "verbs", "X8": "congress_bills",
                       "X9": "spam", "X10": "right_outrage", "X11": "primaries", "X12": "vp_nomination",
                       "X13": "russia", "X14": "hero_RBG_BLM_Lewis", "X15": "arguments", "X16": "fed_investigation",
                       "X17": "social_media", "X18": "healthcare", "X19": "senate_race", "X20": "contractions",
                       "X21": "vote_tomorrow", "X22": "mixture", "X23": "protest", "X24": "scotus",
                       "X25": "institutions", "X26": "climate", "X27": "economy", "X28": "vote_methods",
                       "X29": "knew_had", "X30": "family", "X31": "date_time", "X32": "grateful",
                       "X33": "slang", "X34": "celebrate", "X35": "progress_fight", "X36": "geographic_location",
                       "X37": "food", "X38": "slang_2", "X39": "numbers", "X40": "covid_restrictions", "X41": "trump_2",
                       "X42": "holiday", "X43": "sport", "X44": "news_media", "X45": "no_topic"}
      
#rename topic variables
df = df.rename(columns = topics)

df['log_dem_count'] = np.log(df['dem_count'] + 1)
df['log_rep_count'] = np.log(df['rep_count'] + 1)
df['log_tot_pol'] = np.log(df['rep_count'] + df['dem_count'] + 1)
df['log_total_count'] = np.log(df['total_count'] + 1)
df['log_num_tweets'] = np.log(df['num_tweets'] + 1)
df['norm_emot_50'] = (df['emot_50_mean'] - df['emot_50_mean'].mean()) / df['emot_50_mean'].std()
df['norm_emot_100'] = (df['emot_100_mean'] - df['emot_100_mean'].mean()) / df['emot_100_mean'].std()
df['norm_emot_150'] = (df['emot_150_mean'] - df['emot_150_mean'].mean()) / df['emot_150_mean'].std()
df['norm_emot_200'] = (df['emot_200_mean'] - df['emot_200_mean'].mean()) / df['emot_200_mean'].std()

df['punish_law_log'] = np.log(df['punish_law'] + 1)
df['racism_log'] = np.log(df['racism'] + 1)
df['covid_log'] = np.log(df['covid'] + 1)
df['trump_log'] = np.log(df['trump']+1)
df['congress_bills_log'] = np.log(df['congress_bills']+1)
df['right_outrage_log'] = np.log(df['right_outrage']+1)
df['primaries_log'] = np.log(df['primaries']+1)
df['vp_nomination_log'] = np.log(df['vp_nomination']+1)
df['russia_log'] = np.log(df['russia']+1)
df['fed_investigation_log'] = np.log(df['fed_investigation']+1)
df['arguments_log'] = np.log(df['arguments']+1)
df['social_media_log'] = np.log(df['social_media']+1)
df['healthcare_log'] = np.log(df['healthcare'] + 1)
df['senate_race_log'] = np.log(df['senate_race'] + 1)
df['vote_tomorrow_log'] = np.log(df['vote_tomorrow'] + 1)
df['protest_log'] = np.log(df['protest'] + 1)
df['scotus_log'] = np.log(df['scotus'] + 1)
df['institutions_log'] = np.log(df['institutions'] + 1)
df['climate_log'] = np.log(df['climate'] + 1)
df['economy_log'] = np.log(df['economy'] + 1)
df['vote_methods_log'] = np.log(df['vote_methods'] + 1)
df['progress_fight_log'] = np.log(df['progress_fight'] + 1)
df['covid_restrictions_log'] = np.log(df['covid_restrictions'] + 1)
df['trump_2_log'] = np.log(df['trump_2'] + 1)
df['news_media_log'] = np.log(df['news_media'] + 1)
# Out:
# total original data points: 181770

# %%
print(len(df))
# Out:
# 83432

# %%
#get rep change variable
df.sort_values(['user_id', 'period'], inplace=True)
df['rep_change'] = df.groupby(['user_id', 'school'])['rep_count'].diff()

#get dem change variable
df.sort_values(['user_id', 'period'], inplace=True)
df['dem_change'] = df.groupby(['user_id', 'school'])['dem_count'].diff()

# %%
#individuals that have at least one change
new = df.loc[(df['rep_change'] != 0) | (df['dem_change'] != 0) | (df['num_tweets'] != 0)]

#at least one tweet
new2 = df = df.loc[df['emot_100_mean'] != 0]

print(len(new))
print(len(new2))
# Out:
# 57283
# 54935

# %%
new2.to_csv('/home/twalton_umass_edu/Political Polarization Project/dem_20210428.csv')

# %%
#get base models for all 7 schools
for s in schools:
    school = new[new['school'] == s]
    
    school = school.set_index(['user_id', 'period'])
    
    #rep model
    mod = PanelOLS.from_formula('norm_emot_100 ~ + log_rep_count + log_dem_count + TimeEffects + EntityEffects', school)
    res = mod.fit(cov_type = 'clustered', cluster_entity = True)
    print('####### ' + s + ' ########')
    print(res)
# Out:
# ####### s1 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):              0.0134
# No. Observations:                9779   R-squared (Within):               0.0005
# Date:                Wed, Apr 28 2021   R-squared (Overall):              0.0022
# Time:                        13:23:29   Log-likelihood                -1.131e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.9432
# Entities:                         443   P-value                           0.1433
# Avg Obs:                       22.074   Distribution:                  F(2,9304)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             2.1311
#                                         P-value                           0.1188
# Time periods:                      31   Distribution:                  F(2,9304)
# Avg Obs:                       315.45
# Min Obs:                       262.00
# Max Obs:                       417.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.1197     0.0898     1.3326     0.1827     -0.0564      0.2958
# log_dem_count    -0.1656     0.0849    -1.9507     0.0511     -0.3320      0.0008
# =================================================================================
#
# F-test for Poolability: 17.659
# P-value: 0.0000
# Distribution: F(472,9304)
#
# Included effects: Entity, Time
# ####### s2 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):             -0.0355
# No. Observations:                1309   R-squared (Within):               0.0005
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.0232
# Time:                        13:23:29   Log-likelihood                   -1476.6
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.2536
# Entities:                          57   P-value                           0.7761
# Avg Obs:                       22.965   Distribution:                  F(2,1220)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             0.2760
#                                         P-value                           0.7588
# Time periods:                      31   Distribution:                  F(2,1220)
# Avg Obs:                       42.226
# Min Obs:                       32.000
# Max Obs:                       56.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.2740     0.3841     0.7134     0.4757     -0.4795      1.0275
# log_dem_count    -0.1177     0.1743    -0.6753     0.4996     -0.4597      0.2243
# =================================================================================
#
# F-test for Poolability: 10.508
# P-value: 0.0000
# Distribution: F(86,1220)
#
# Included effects: Entity, Time
# ####### s3 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):              0.1026
# No. Observations:                9553   R-squared (Within):               0.0005
# Date:                Wed, Apr 28 2021   R-squared (Overall):              0.0595
# Time:                        13:23:30   Log-likelihood                -1.137e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.7820
# Entities:                         453   P-value                           0.1684
# Avg Obs:                       21.088   Distribution:                  F(2,9068)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             1.9610
#                                         P-value                           0.1408
# Time periods:                      31   Distribution:                  F(2,9068)
# Avg Obs:                       308.16
# Min Obs:                       256.00
# Max Obs:                       442.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.2199     0.1237     1.7779     0.0755     -0.0226      0.4624
# log_dem_count    -0.1432     0.1508    -0.9494     0.3424     -0.4387      0.1524
# =================================================================================
#
# F-test for Poolability: 16.895
# P-value: 0.0000
# Distribution: F(482,9068)
#
# Included effects: Entity, Time
# ####### s4 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0001
# Estimator:                   PanelOLS   R-squared (Between):             -0.1443
# No. Observations:                5978   R-squared (Within):            -3.38e-05
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.0680
# Time:                        13:23:30   Log-likelihood                   -7146.4
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.3680
# Entities:                         299   P-value                           0.6921
# Avg Obs:                       19.993   Distribution:                  F(2,5647)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             0.1372
#                                         P-value                           0.8718
# Time periods:                      31   Distribution:                  F(2,5647)
# Avg Obs:                       192.84
# Min Obs:                       164.00
# Max Obs:                       292.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count    -0.1329     0.2555    -0.5203     0.6029     -0.6338      0.3679
# log_dem_count     0.0562     0.3908     0.1437     0.8858     -0.7100      0.8223
# =================================================================================
#
# F-test for Poolability: 12.509
# P-value: 0.0000
# Distribution: F(328,5647)
#
# Included effects: Entity, Time
# ####### s5 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                     5.921e-05
# Estimator:                   PanelOLS   R-squared (Between):              0.0332
# No. Observations:               14968   R-squared (Within):               0.0001
# Date:                Wed, Apr 28 2021   R-squared (Overall):              0.0316
# Time:                        13:23:30   Log-likelihood                -1.721e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.4223
# Entities:                         671   P-value                           0.6555
# Avg Obs:                       22.307   Distribution:                 F(2,14265)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             0.3846
#                                         P-value                           0.6807
# Time periods:                      31   Distribution:                 F(2,14265)
# Avg Obs:                       482.84
# Min Obs:                       418.00
# Max Obs:                       660.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count    -0.0383     0.0884    -0.4326     0.6653     -0.2116      0.1351
# log_dem_count    -0.0649     0.0972    -0.6676     0.5044     -0.2554      0.1256
# =================================================================================
#
# F-test for Poolability: 16.953
# P-value: 0.0000
# Distribution: F(700,14265)
#
# Included effects: Entity, Time
# ####### s6 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0002
# Estimator:                   PanelOLS   R-squared (Between):             -0.0093
# No. Observations:                4184   R-squared (Within):               0.0003
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.0140
# Time:                        13:23:31   Log-likelihood                   -4967.8
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.3967
# Entities:                         209   P-value                           0.6726
# Avg Obs:                       20.019   Distribution:                  F(2,3943)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             0.1740
#                                         P-value                           0.8403
# Time periods:                      31   Distribution:                  F(2,3943)
# Avg Obs:                       134.97
# Min Obs:                       120.00
# Max Obs:                       208.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.1591     0.2911     0.5465     0.5848     -0.4116      0.7297
# log_dem_count    -0.0504     0.1464    -0.3439     0.7309     -0.3374      0.2367
# =================================================================================
#
# F-test for Poolability: 15.279
# P-value: 0.0000
# Distribution: F(238,3943)
#
# Included effects: Entity, Time
# ####### s8 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):             -1.3557
# No. Observations:               11512   R-squared (Within):            5.472e-05
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.6888
# Time:                        13:23:31   Log-likelihood                -1.293e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.1539
# Entities:                         577   P-value                           0.1161
# Avg Obs:                       19.951   Distribution:                 F(2,10903)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             2.8714
#                                         P-value                           0.0567
# Time periods:                      31   Distribution:                 F(2,10903)
# Avg Obs:                       371.35
# Min Obs:                       299.00
# Max Obs:                       561.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.0503     0.0771     0.6518     0.5145     -0.1009      0.2015
# log_dem_count     0.1766     0.0861     2.0517     0.0402      0.0079      0.3453
# =================================================================================
#
# F-test for Poolability: 15.834
# P-value: 0.0000
# Distribution: F(606,10903)
#
# Included effects: Entity, Time

# %%
#get base models for all 7 schools
for s in schools:
    school = new[new['school'] == s]
    
    school = school.set_index(['user_id', 'period'])
    
    #rep model
    mod = PanelOLS.from_formula('norm_emot_100 ~ + log_rep_count + log_dem_count + punish_law_log + racism_log + covid_log + trump_log + congress_bills_log + right_outrage_log + primaries_log + vp_nomination_log + russia_log + fed_investigation_log + arguments_log + social_media_log + healthcare_log + senate_race_log + vote_tomorrow_log + protest_log + scotus_log + institutions_log + climate_log + economy_log + vote_methods_log + progress_fight_log + covid_restrictions_log + trump_2_log + news_media_log + vp_nomination_log + social_media_log + senate_race_log + progress_fight_log + TimeEffects + EntityEffects', school)
    res = mod.fit(cov_type = 'clustered', cluster_entity = True)
    print('####### ' + s + ' ########')
    print(res)
# Out:
# ####### s1 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0367
# Estimator:                   PanelOLS   R-squared (Between):              0.1288
# No. Observations:                9779   R-squared (Within):               0.0473
# Date:                Wed, Apr 28 2021   R-squared (Overall):              0.1068
# Time:                        13:23:43   Log-likelihood                -1.113e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      13.109
# Entities:                         443   P-value                           0.0000
# Avg Obs:                       22.074   Distribution:                 F(27,9279)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             12.784
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(27,9279)
# Avg Obs:                       315.45
# Min Obs:                       262.00
# Max Obs:                       417.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.1022     0.0919     1.1130     0.2657     -0.0778      0.2823
# log_dem_count             -0.1650     0.0767    -2.1502     0.0316     -0.3154     -0.0146
# punish_law_log             0.1688     0.0259     6.5184     0.0000      0.1180      0.2195
# racism_log                 0.1336     0.0188     7.1153     0.0000      0.0968      0.1704
# covid_log                  0.0946     0.0203     4.6499     0.0000      0.0547      0.1345
# trump_log                  0.1078     0.0196     5.5006     0.0000      0.0694      0.1462
# congress_bills_log         0.0148     0.0226     0.6541     0.5130     -0.0295      0.0591
# right_outrage_log          0.1608     0.0258     6.2329     0.0000      0.1103      0.2114
# primaries_log             -0.0123     0.0226    -0.5467     0.5846     -0.0566      0.0319
# vp_nomination_log         -0.0979     0.0200    -4.8893     0.0000     -0.1371     -0.0586
# russia_log                 0.0147     0.0246     0.5955     0.5516     -0.0336      0.0629
# fed_investigation_log      0.0975     0.0231     4.2199     0.0000      0.0522      0.1429
# arguments_log              0.0501     0.0191     2.6187     0.0088      0.0126      0.0876
# social_media_log          -0.1512     0.0192    -7.8709     0.0000     -0.1888     -0.1135
# healthcare_log             0.0374     0.0204     1.8330     0.0668     -0.0026      0.0773
# senate_race_log           -0.0642     0.0190    -3.3744     0.0007     -0.1015     -0.0269
# vote_tomorrow_log         -0.1089     0.0153    -7.1017     0.0000     -0.1390     -0.0789
# protest_log                0.1220     0.0199     6.1384     0.0000      0.0831      0.1610
# scotus_log                -0.0105     0.0209    -0.5009     0.6165     -0.0514      0.0305
# institutions_log           0.0860     0.0205     4.1932     0.0000      0.0458      0.1262
# climate_log                0.0168     0.0190     0.8848     0.3763     -0.0205      0.0541
# economy_log                0.0124     0.0173     0.7173     0.4732     -0.0215      0.0463
# vote_methods_log          -0.0202     0.0189    -1.0694     0.2849     -0.0572      0.0168
# progress_fight_log        -0.0821     0.0196    -4.1892     0.0000     -0.1205     -0.0437
# covid_restrictions_log    -0.0370     0.0160    -2.3078     0.0210     -0.0685     -0.0056
# trump_2_log                0.1078     0.0253     4.2633     0.0000      0.0582      0.1573
# news_media_log            -0.0086     0.0221    -0.3910     0.6958     -0.0519      0.0347
# ==========================================================================================
#
# F-test for Poolability: 14.105
# P-value: 0.0000
# Distribution: F(472,9279)
#
# Included effects: Entity, Time
# ####### s2 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0476
# Estimator:                   PanelOLS   R-squared (Between):             -0.1951
# No. Observations:                1309   R-squared (Within):               0.0513
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.1166
# Time:                        13:23:43   Log-likelihood                   -1445.0
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.2102
# Entities:                          57   P-value                           0.0004
# Avg Obs:                       22.965   Distribution:                 F(27,1195)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             4.9687
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(27,1195)
# Avg Obs:                       42.226
# Min Obs:                       32.000
# Max Obs:                       56.000
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.3879     0.3602     1.0768     0.2818     -0.3189      1.0947
# log_dem_count             -0.1461     0.1557    -0.9387     0.3481     -0.4516      0.1593
# punish_law_log             0.3582     0.1128     3.1764     0.0015      0.1370      0.5795
# racism_log                 0.2155     0.0750     2.8739     0.0041      0.0684      0.3625
# covid_log                  0.0490     0.0527     0.9294     0.3529     -0.0544      0.1524
# trump_log                  0.2208     0.0810     2.7248     0.0065      0.0618      0.3799
# congress_bills_log         0.0277     0.0712     0.3895     0.6970     -0.1119      0.1673
# right_outrage_log          0.1567     0.1010     1.5518     0.1210     -0.0414      0.3548
# primaries_log             -0.1152     0.0628    -1.8335     0.0670     -0.2385      0.0081
# vp_nomination_log         -0.1614     0.0722    -2.2362     0.0255     -0.3030     -0.0198
# russia_log                -0.0217     0.1308    -0.1656     0.8685     -0.2782      0.2349
# fed_investigation_log      0.1808     0.0624     2.8973     0.0038      0.0584      0.3033
# arguments_log              0.0453     0.0683     0.6629     0.5075     -0.0888      0.1794
# social_media_log          -0.1109     0.0513    -2.1627     0.0308     -0.2116     -0.0103
# healthcare_log             0.1531     0.0488     3.1385     0.0017      0.0574      0.2488
# senate_race_log           -0.1708     0.0613    -2.7869     0.0054     -0.2910     -0.0506
# vote_tomorrow_log         -0.0283     0.0513    -0.5522     0.5809     -0.1289      0.0723
# protest_log                0.1522     0.0591     2.5739     0.0102      0.0362      0.2682
# scotus_log                 0.0347     0.0677     0.5127     0.6082     -0.0981      0.1675
# institutions_log          -0.0284     0.0530    -0.5361     0.5920     -0.1325      0.0756
# climate_log                0.0101     0.0536     0.1880     0.8509     -0.0952      0.1153
# economy_log                0.0325     0.0500     0.6513     0.5150     -0.0655      0.1305
# vote_methods_log           0.0077     0.0682     0.1129     0.9101     -0.1262      0.1416
# progress_fight_log        -0.0663     0.0587    -1.1285     0.2593     -0.1816      0.0490
# covid_restrictions_log    -0.0295     0.0452    -0.6537     0.5134     -0.1181      0.0591
# trump_2_log                0.3171     0.1410     2.2487     0.0247      0.0404      0.5937
# news_media_log             0.0685     0.0720     0.9519     0.3413     -0.0727      0.2098
# ==========================================================================================
#
# F-test for Poolability: 9.1382
# P-value: 0.0000
# Distribution: F(86,1195)
#
# Included effects: Entity, Time
# ####### s3 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0405
# Estimator:                   PanelOLS   R-squared (Between):              0.1602
# No. Observations:                9553   R-squared (Within):               0.0431
# Date:                Wed, Apr 28 2021   R-squared (Overall):              0.1215
# Time:                        13:23:44   Log-likelihood                -1.117e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      14.137
# Entities:                         453   P-value                           0.0000
# Avg Obs:                       21.088   Distribution:                 F(27,9043)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             17.358
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(27,9043)
# Avg Obs:                       308.16
# Min Obs:                       256.00
# Max Obs:                       442.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.1833     0.1230     1.4904     0.1362     -0.0578      0.4244
# log_dem_count             -0.0927     0.1503    -0.6170     0.5373     -0.3873      0.2019
# punish_law_log             0.1328     0.0232     5.7165     0.0000      0.0872      0.1783
# racism_log                 0.0929     0.0190     4.8816     0.0000      0.0556      0.1302
# covid_log                  0.0689     0.0188     3.6682     0.0002      0.0321      0.1057
# trump_log                  0.0919     0.0184     4.9868     0.0000      0.0558      0.1280
# congress_bills_log         0.0101     0.0202     0.4981     0.6184     -0.0296      0.0497
# right_outrage_log          0.1141     0.0277     4.1149     0.0000      0.0598      0.1685
# primaries_log             -0.0015     0.0196    -0.0775     0.9382     -0.0400      0.0370
# vp_nomination_log         -0.1172     0.0179    -6.5512     0.0000     -0.1523     -0.0822
# russia_log                -0.0223     0.0273    -0.8191     0.4128     -0.0758      0.0311
# fed_investigation_log      0.0833     0.0210     3.9663     0.0001      0.0421      0.1245
# arguments_log              0.0418     0.0233     1.7935     0.0729     -0.0039      0.0874
# social_media_log          -0.1404     0.0162    -8.6929     0.0000     -0.1721     -0.1088
# healthcare_log             0.0771     0.0181     4.2617     0.0000      0.0416      0.1126
# senate_race_log           -0.1429     0.0171    -8.3776     0.0000     -0.1763     -0.1094
# vote_tomorrow_log         -0.1299     0.0154    -8.4440     0.0000     -0.1600     -0.0997
# protest_log                0.1396     0.0212     6.5846     0.0000      0.0981      0.1812
# scotus_log                -0.0432     0.0177    -2.4447     0.0145     -0.0779     -0.0086
# institutions_log           0.0707     0.0188     3.7560     0.0002      0.0338      0.1076
# climate_log                0.0565     0.0179     3.1624     0.0016      0.0215      0.0915
# economy_log                0.0254     0.0176     1.4441     0.1488     -0.0091      0.0600
# vote_methods_log           0.0181     0.0178     1.0191     0.3082     -0.0167      0.0530
# progress_fight_log        -0.0755     0.0178    -4.2497     0.0000     -0.1104     -0.0407
# covid_restrictions_log    -0.0432     0.0145    -2.9816     0.0029     -0.0717     -0.0148
# trump_2_log                0.1799     0.0247     7.2817     0.0000      0.1315      0.2284
# news_media_log            -0.0010     0.0195    -0.0521     0.9585     -0.0392      0.0372
# ==========================================================================================
#
# F-test for Poolability: 12.855
# P-value: 0.0000
# Distribution: F(482,9043)
#
# Included effects: Entity, Time
# ####### s4 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0364
# Estimator:                   PanelOLS   R-squared (Between):             -0.1224
# No. Observations:                5978   R-squared (Within):               0.0427
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.0280
# Time:                        13:23:44   Log-likelihood                   -7035.9
# Cov. Estimator:             Clustered
#                                         F-statistic:                      7.8681
# Entities:                         299   P-value                           0.0000
# Avg Obs:                       19.993   Distribution:                 F(27,5622)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             8.6964
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(27,5622)
# Avg Obs:                       192.84
# Min Obs:                       164.00
# Max Obs:                       292.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count             -0.1334     0.2189    -0.6094     0.5423     -0.5625      0.2957
# log_dem_count              0.0632     0.3963     0.1595     0.8733     -0.7137      0.8401
# punish_law_log             0.1424     0.0314     4.5281     0.0000      0.0807      0.2040
# racism_log                 0.1198     0.0247     4.8484     0.0000      0.0714      0.1683
# covid_log                  0.1384     0.0268     5.1603     0.0000      0.0858      0.1910
# trump_log                  0.1482     0.0305     4.8638     0.0000      0.0885      0.2080
# congress_bills_log         0.0212     0.0248     0.8559     0.3921     -0.0274      0.0697
# right_outrage_log          0.1493     0.0330     4.5187     0.0000      0.0845      0.2141
# primaries_log             -0.0025     0.0251    -0.1014     0.9192     -0.0517      0.0466
# vp_nomination_log         -0.1007     0.0229    -4.3971     0.0000     -0.1456     -0.0558
# russia_log                -0.0015     0.0305    -0.0507     0.9595     -0.0613      0.0582
# fed_investigation_log      0.0713     0.0223     3.2005     0.0014      0.0276      0.1149
# arguments_log              0.0338     0.0275     1.2286     0.2193     -0.0201      0.0877
# social_media_log          -0.1423     0.0212    -6.7021     0.0000     -0.1839     -0.1006
# healthcare_log             0.0762     0.0295     2.5856     0.0097      0.0184      0.1339
# senate_race_log           -0.1183     0.0246    -4.8073     0.0000     -0.1665     -0.0700
# vote_tomorrow_log         -0.1040     0.0239    -4.3536     0.0000     -0.1508     -0.0572
# protest_log                0.0859     0.0240     3.5864     0.0003      0.0389      0.1329
# scotus_log                 0.0234     0.0263     0.8925     0.3722     -0.0281      0.0750
# institutions_log           0.0712     0.0260     2.7336     0.0063      0.0201      0.1222
# climate_log                0.0383     0.0213     1.7981     0.0722     -0.0035      0.0801
# economy_log                0.0265     0.0208     1.2745     0.2026     -0.0143      0.0672
# vote_methods_log          -0.0119     0.0278    -0.4288     0.6681     -0.0665      0.0426
# progress_fight_log        -0.1130     0.0245    -4.6064     0.0000     -0.1611     -0.0649
# covid_restrictions_log    -0.0722     0.0225    -3.2052     0.0014     -0.1163     -0.0280
# trump_2_log                0.1157     0.0338     3.4254     0.0006      0.0495      0.1820
# news_media_log             0.0595     0.0247     2.4033     0.0163      0.0110      0.1080
# ==========================================================================================
#
# F-test for Poolability: 9.7266
# P-value: 0.0000
# Distribution: F(328,5622)
#
# Included effects: Entity, Time
# ####### s5 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0358
# Estimator:                   PanelOLS   R-squared (Between):              0.1204
# No. Observations:               14968   R-squared (Within):               0.0406
# Date:                Wed, Apr 28 2021   R-squared (Overall):              0.0987
# Time:                        13:23:45   Log-likelihood                -1.694e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      19.577
# Entities:                         671   P-value                           0.0000
# Avg Obs:                       22.307   Distribution:                F(27,14240)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             22.974
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                F(27,14240)
# Avg Obs:                       482.84
# Min Obs:                       418.00
# Max Obs:                       660.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count             -0.0141     0.0854    -0.1646     0.8693     -0.1815      0.1534
# log_dem_count             -0.0141     0.0939    -0.1498     0.8809     -0.1982      0.1700
# punish_law_log             0.0981     0.0152     6.4394     0.0000      0.0682      0.1279
# racism_log                 0.1327     0.0137     9.7146     0.0000      0.1060      0.1595
# covid_log                  0.0523     0.0130     4.0366     0.0001      0.0269      0.0777
# trump_log                  0.0844     0.0145     5.8297     0.0000      0.0560      0.1128
# congress_bills_log        -0.0523     0.0128    -4.0746     0.0000     -0.0774     -0.0271
# right_outrage_log          0.1042     0.0159     6.5636     0.0000      0.0731      0.1353
# primaries_log              0.0012     0.0137     0.0911     0.9274     -0.0256      0.0281
# vp_nomination_log         -0.1173     0.0147    -7.9575     0.0000     -0.1462     -0.0884
# russia_log                 0.0131     0.0138     0.9541     0.3400     -0.0139      0.0401
# fed_investigation_log      0.0433     0.0136     3.1914     0.0014      0.0167      0.0699
# arguments_log              0.0556     0.0141     3.9528     0.0001      0.0280      0.0832
# social_media_log          -0.1159     0.0135    -8.5790     0.0000     -0.1423     -0.0894
# healthcare_log             0.0723     0.0132     5.4728     0.0000      0.0464      0.0982
# senate_race_log           -0.0841     0.0134    -6.2847     0.0000     -0.1104     -0.0579
# vote_tomorrow_log         -0.1325     0.0132    -10.019     0.0000     -0.1584     -0.1066
# protest_log                0.0999     0.0142     7.0386     0.0000      0.0721      0.1277
# scotus_log                -0.0416     0.0127    -3.2667     0.0011     -0.0665     -0.0166
# institutions_log           0.0397     0.0128     3.1130     0.0019      0.0147      0.0647
# climate_log                0.0633     0.0140     4.5354     0.0000      0.0359      0.0906
# economy_log                0.0471     0.0139     3.3897     0.0007      0.0199      0.0744
# vote_methods_log           0.0016     0.0125     0.1318     0.8951     -0.0228      0.0261
# progress_fight_log        -0.0890     0.0142    -6.2869     0.0000     -0.1168     -0.0613
# covid_restrictions_log    -0.0432     0.0121    -3.5815     0.0003     -0.0668     -0.0195
# trump_2_log                0.1380     0.0154     8.9626     0.0000      0.1079      0.1682
# news_media_log             0.0098     0.0133     0.7380     0.4606     -0.0163      0.0359
# ==========================================================================================
#
# F-test for Poolability: 13.299
# P-value: 0.0000
# Distribution: F(700,14240)
#
# Included effects: Entity, Time
# ####### s6 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0330
# Estimator:                   PanelOLS   R-squared (Between):             -0.0839
# No. Observations:                4184   R-squared (Within):               0.0360
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.0445
# Time:                        13:23:45   Log-likelihood                   -4898.2
# Cov. Estimator:             Clustered
#                                         F-statistic:                      4.9454
# Entities:                         209   P-value                           0.0000
# Avg Obs:                       20.019   Distribution:                 F(27,3918)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             6.9524
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(27,3918)
# Avg Obs:                       134.97
# Min Obs:                       120.00
# Max Obs:                       208.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.1545     0.2717     0.5685     0.5698     -0.3783      0.6872
# log_dem_count             -0.0059     0.1461    -0.0406     0.9676     -0.2923      0.2805
# punish_law_log             0.1094     0.0420     2.6005     0.0093      0.0269      0.1918
# racism_log                 0.1425     0.0503     2.8356     0.0046      0.0440      0.2411
# covid_log                  0.0755     0.0279     2.7058     0.0068      0.0208      0.1302
# trump_log                  0.0480     0.0341     1.4068     0.1596     -0.0189      0.1149
# congress_bills_log         0.0123     0.0255     0.4824     0.6295     -0.0377      0.0623
# right_outrage_log          0.1623     0.0377     4.3080     0.0000      0.0884      0.2361
# primaries_log             -0.0205     0.0286    -0.7154     0.4744     -0.0765      0.0356
# vp_nomination_log         -0.1178     0.0320    -3.6836     0.0002     -0.1805     -0.0551
# russia_log                 0.0088     0.0369     0.2395     0.8107     -0.0635      0.0811
# fed_investigation_log      0.0704     0.0349     2.0165     0.0438      0.0020      0.1389
# arguments_log              0.0490     0.0380     1.2906     0.1969     -0.0255      0.1236
# social_media_log          -0.1247     0.0306    -4.0735     0.0000     -0.1847     -0.0647
# healthcare_log             0.0188     0.0266     0.7065     0.4799     -0.0334      0.0710
# senate_race_log           -0.1500     0.0283    -5.3006     0.0000     -0.2054     -0.0945
# vote_tomorrow_log         -0.1398     0.0285    -4.9076     0.0000     -0.1957     -0.0840
# protest_log                0.1461     0.0411     3.5561     0.0004      0.0656      0.2267
# scotus_log                -0.0456     0.0268    -1.7028     0.0887     -0.0981      0.0069
# institutions_log           0.0491     0.0309     1.5920     0.1115     -0.0114      0.1097
# climate_log               -0.0088     0.0251    -0.3523     0.7246     -0.0580      0.0403
# economy_log                0.0091     0.0285     0.3186     0.7501     -0.0468      0.0650
# vote_methods_log           0.0263     0.0318     0.8260     0.4089     -0.0361      0.0887
# progress_fight_log        -0.1008     0.0308    -3.2781     0.0011     -0.1611     -0.0405
# covid_restrictions_log    -0.0684     0.0321    -2.1297     0.0333     -0.1314     -0.0054
# trump_2_log                0.1251     0.0416     3.0048     0.0027      0.0435      0.2068
# news_media_log             0.0080     0.0314     0.2553     0.7985     -0.0536      0.0697
# ==========================================================================================
#
# F-test for Poolability: 12.115
# P-value: 0.0000
# Distribution: F(238,3918)
#
# Included effects: Entity, Time
# ####### s8 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0381
# Estimator:                   PanelOLS   R-squared (Between):             -0.8189
# No. Observations:               11512   R-squared (Within):               0.0461
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.3929
# Time:                        13:23:45   Log-likelihood                -1.271e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      15.942
# Entities:                         577   P-value                           0.0000
# Avg Obs:                       19.951   Distribution:                F(27,10878)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             18.127
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                F(27,10878)
# Avg Obs:                       371.35
# Min Obs:                       299.00
# Max Obs:                       561.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.0440     0.0749     0.5871     0.5571     -0.1028      0.1907
# log_dem_count              0.1373     0.0803     1.7098     0.0873     -0.0201      0.2946
# punish_law_log             0.1220     0.0177     6.9070     0.0000      0.0874      0.1566
# racism_log                 0.0913     0.0132     6.9263     0.0000      0.0655      0.1171
# covid_log                  0.0885     0.0158     5.5824     0.0000      0.0574      0.1195
# trump_log                  0.0725     0.0161     4.5151     0.0000      0.0410      0.1040
# congress_bills_log        -0.0174     0.0151    -1.1508     0.2498     -0.0471      0.0122
# right_outrage_log          0.1560     0.0191     8.1453     0.0000      0.1184      0.1935
# primaries_log             -0.0065     0.0151    -0.4285     0.6683     -0.0360      0.0231
# vp_nomination_log         -0.1141     0.0153    -7.4472     0.0000     -0.1441     -0.0840
# russia_log                 0.0252     0.0168     1.5030     0.1329     -0.0077      0.0582
# fed_investigation_log      0.0507     0.0143     3.5392     0.0004      0.0226      0.0788
# arguments_log              0.0521     0.0153     3.4067     0.0007      0.0221      0.0821
# social_media_log          -0.1221     0.0155    -7.8652     0.0000     -0.1526     -0.0917
# healthcare_log             0.0305     0.0153     1.9955     0.0460      0.0005      0.0605
# senate_race_log           -0.1185     0.0145    -8.1934     0.0000     -0.1469     -0.0902
# vote_tomorrow_log         -0.1375     0.0143    -9.5855     0.0000     -0.1656     -0.1094
# protest_log                0.1408     0.0155     9.1035     0.0000      0.1104      0.1711
# scotus_log                -0.0229     0.0148    -1.5408     0.1234     -0.0519      0.0062
# institutions_log           0.0373     0.0152     2.4559     0.0141      0.0075      0.0670
# climate_log                0.0277     0.0144     1.9329     0.0533     -0.0004      0.0559
# economy_log                0.0335     0.0138     2.4261     0.0153      0.0064      0.0606
# vote_methods_log          -0.0252     0.0145    -1.7369     0.0824     -0.0537      0.0032
# progress_fight_log        -0.0778     0.0167    -4.6751     0.0000     -0.1105     -0.0452
# covid_restrictions_log    -0.0522     0.0136    -3.8284     0.0001     -0.0789     -0.0255
# trump_2_log                0.0767     0.0185     4.1395     0.0000      0.0404      0.1131
# news_media_log             0.0038     0.0151     0.2517     0.8013     -0.0258      0.0335
# ==========================================================================================
#
# F-test for Poolability: 12.841
# P-value: 0.0000
# Distribution: F(606,10878)
#
# Included effects: Entity, Time

# %%
#read in most recent final product
df = pd.read_csv('/home/twalton_umass_edu/Political Polarization Project/final/final_product_20210407.csv')

#list of schools to loop through
schools = ['s1', 's2', 's3', 's4', 's5', 's6', 's8']

#only want republicans
df = df[df['dem_org'] == 1]

#number of data points
print('total original data points: ' + str(len(df)))
      
#get rid of first three period due to missing ties
df = df[(df['period'] >= 4)]

df = df.groupby(['user_id', 'school']).filter(lambda x: len(x) > 25)
    
#fill in nans with 0
df = df.fillna(0)
      
#create new variable that is the variance of the rep count for each user_id/school pair
df = df.join(df.groupby(['user_id', 'school'])['rep_count'].var(), on = ['user_id', 'school'], rsuffix = '_var')

#create new variable that is the variance of the dem_coutn for each user_id/school pair
df = df.join(df.groupby(['user_id', 'school'])['dem_count'].var(), on = ['user_id', 'school'], rsuffix = '_var')

#create a new variable that is the total number of tweets for the individual
df = df.join(df.groupby(['user_id', 'school'])['num_tweets'].sum(), on = ['user_id', 'school'], rsuffix = '_sum')

#keep usee that have at least both variance or at least one tweet
df = df[(df['num_tweets_sum'] != 0) | ((df['dem_count_var'] != 0) & (df['rep_count_var'] != 0))]

      
topics = {"X0": "education", "X1": "names", "X2": "punish_law", "X3": "racism",
                       "X4": "covid", "X5": "event", "X6": "trump", "X7": "verbs", "X8": "congress_bills",
                       "X9": "spam", "X10": "right_outrage", "X11": "primaries", "X12": "vp_nomination",
                       "X13": "russia", "X14": "hero_RBG_BLM_Lewis", "X15": "arguments", "X16": "fed_investigation",
                       "X17": "social_media", "X18": "healthcare", "X19": "senate_race", "X20": "contractions",
                       "X21": "vote_tomorrow", "X22": "mixture", "X23": "protest", "X24": "scotus",
                       "X25": "institutions", "X26": "climate", "X27": "economy", "X28": "vote_methods",
                       "X29": "knew_had", "X30": "family", "X31": "date_time", "X32": "grateful",
                       "X33": "slang", "X34": "celebrate", "X35": "progress_fight", "X36": "geographic_location",
                       "X37": "food", "X38": "slang_2", "X39": "numbers", "X40": "covid_restrictions", "X41": "trump_2",
                       "X42": "holiday", "X43": "sport", "X44": "news_media", "X45": "no_topic"}
      
#rename topic variables
df = df.rename(columns = topics)

df['log_dem_count'] = np.log(df['dem_count'] + 1)
df['log_rep_count'] = np.log(df['rep_count'] + 1)
df['log_tot_pol'] = np.log(df['rep_count'] + df['dem_count'] + 1)
df['log_total_count'] = np.log(df['total_count'] + 1)
df['log_num_tweets'] = np.log(df['num_tweets'] + 1)
df['norm_emot_50'] = (df['emot_50_mean'] - df['emot_50_mean'].mean()) / df['emot_50_mean'].std()
df['norm_emot_100'] = (df['emot_100_mean'] - df['emot_100_mean'].mean()) / df['emot_100_mean'].std()
df['norm_emot_150'] = (df['emot_150_mean'] - df['emot_150_mean'].mean()) / df['emot_150_mean'].std()
df['norm_emot_200'] = (df['emot_200_mean'] - df['emot_200_mean'].mean()) / df['emot_200_mean'].std()

df['punish_law_log'] = np.log(df['punish_law'] + 1)
df['racism_log'] = np.log(df['racism'] + 1)
df['covid_log'] = np.log(df['covid'] + 1)
df['trump_log'] = np.log(df['trump']+1)
df['congress_bills_log'] = np.log(df['congress_bills']+1)
df['right_outrage_log'] = np.log(df['right_outrage']+1)
df['primaries_log'] = np.log(df['primaries']+1)
df['vp_nomination_log'] = np.log(df['vp_nomination']+1)
df['russia_log'] = np.log(df['russia']+1)
df['fed_investigation_log'] = np.log(df['fed_investigation']+1)
df['arguments_log'] = np.log(df['arguments']+1)
df['social_media_log'] = np.log(df['social_media']+1)
df['healthcare_log'] = np.log(df['healthcare'] + 1)
df['senate_race_log'] = np.log(df['senate_race'] + 1)
df['vote_tomorrow_log'] = np.log(df['vote_tomorrow'] + 1)
df['protest_log'] = np.log(df['protest'] + 1)
df['scotus_log'] = np.log(df['scotus'] + 1)
df['institutions_log'] = np.log(df['institutions'] + 1)
df['climate_log'] = np.log(df['climate'] + 1)
df['economy_log'] = np.log(df['economy'] + 1)
df['vote_methods_log'] = np.log(df['vote_methods'] + 1)
df['progress_fight_log'] = np.log(df['progress_fight'] + 1)
df['covid_restrictions_log'] = np.log(df['covid_restrictions'] + 1)
df['trump_2_log'] = np.log(df['trump_2'] + 1)
df['news_media_log'] = np.log(df['news_media'] + 1)
# Out:
# total original data points: 181770

# %%
#get rep change variable
df.sort_values(['user_id', 'period'], inplace=True)
df['rep_change'] = df.groupby(['user_id', 'school'])['rep_count'].diff()

#get dem change variable
df.sort_values(['user_id', 'period'], inplace=True)
df['dem_change'] = df.groupby(['user_id', 'school'])['dem_count'].diff()

#individuals that have at least one change
new = df.loc[(df['rep_change'] != 0) | (df['dem_change'] != 0) | (df['num_tweets'] != 0)]

#at least one tweet
new2 = df = df.loc[df['emot_100_mean'] != 0]

print(len(new))
print(len(new2))
# Out:
# 57283
# 54935

# %%
#get base models for all 7 schools
for s in schools:
    school = new[new['school'] == s]
    
    school = school.set_index(['user_id', 'period'])
    
    #rep model
    mod = PanelOLS.from_formula('emot_100_mean ~ + log_rep_count + log_dem_count + TimeEffects + EntityEffects', school)
    res = mod.fit(cov_type = 'clustered', cluster_entity = True)
    print('####### ' + s + ' ########')
    print(res)
# Out:
# ####### s1 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):              0.4051
# No. Observations:                9779   R-squared (Within):               0.0005
# Date:                Fri, Apr 16 2021   R-squared (Overall):              0.3046
# Time:                        18:33:54   Log-likelihood                 1.007e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.9432
# Entities:                         443   P-value                           0.1433
# Avg Obs:                       22.074   Distribution:                  F(2,9304)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             2.1311
#                                         P-value                           0.1188
# Time periods:                      31   Distribution:                  F(2,9304)
# Avg Obs:                       315.45
# Min Obs:                       262.00
# Max Obs:                       417.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.0134     0.0101     1.3326     0.1827     -0.0063      0.0332
# log_dem_count    -0.0186     0.0095    -1.9507     0.0511     -0.0373   9.107e-05
# =================================================================================
#
# F-test for Poolability: 17.659
# P-value: 0.0000
# Distribution: F(472,9304)
#
# Included effects: Entity, Time
# ####### s2 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):              0.0505
# No. Observations:                1309   R-squared (Within):               0.0005
# Date:                Fri, Apr 16 2021   R-squared (Overall):              0.0356
# Time:                        18:33:55   Log-likelihood                    1385.4
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.2536
# Entities:                          57   P-value                           0.7761
# Avg Obs:                       22.965   Distribution:                  F(2,1220)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             0.2760
#                                         P-value                           0.7588
# Time periods:                      31   Distribution:                  F(2,1220)
# Avg Obs:                       42.226
# Min Obs:                       32.000
# Max Obs:                       56.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.0308     0.0431     0.7134     0.4757     -0.0539      0.1154
# log_dem_count    -0.0132     0.0196    -0.6753     0.4996     -0.0516      0.0252
# =================================================================================
#
# F-test for Poolability: 10.508
# P-value: 0.0000
# Distribution: F(86,1220)
#
# Included effects: Entity, Time
# ####### s3 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):              0.2703
# No. Observations:                9553   R-squared (Within):               0.0005
# Date:                Fri, Apr 16 2021   R-squared (Overall):              0.1959
# Time:                        18:33:55   Log-likelihood                    9521.4
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.7820
# Entities:                         453   P-value                           0.1684
# Avg Obs:                       21.088   Distribution:                  F(2,9068)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             1.9610
#                                         P-value                           0.1408
# Time periods:                      31   Distribution:                  F(2,9068)
# Avg Obs:                       308.16
# Min Obs:                       256.00
# Max Obs:                       442.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.0247     0.0139     1.7779     0.0755     -0.0025      0.0519
# log_dem_count    -0.0161     0.0169    -0.9494     0.3424     -0.0493      0.0171
# =================================================================================
#
# F-test for Poolability: 16.895
# P-value: 0.0000
# Distribution: F(482,9068)
#
# Included effects: Entity, Time
# ####### s4 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0001
# Estimator:                   PanelOLS   R-squared (Between):             -0.1097
# No. Observations:                5978   R-squared (Within):            -3.38e-05
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.0728
# Time:                        18:33:55   Log-likelihood                    5924.0
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.3680
# Entities:                         299   P-value                           0.6921
# Avg Obs:                       19.993   Distribution:                  F(2,5647)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             0.1372
#                                         P-value                           0.8718
# Time periods:                      31   Distribution:                  F(2,5647)
# Avg Obs:                       192.84
# Min Obs:                       164.00
# Max Obs:                       292.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count    -0.0149     0.0287    -0.5203     0.6029     -0.0712      0.0413
# log_dem_count     0.0063     0.0439     0.1437     0.8858     -0.0797      0.0924
# =================================================================================
#
# F-test for Poolability: 12.509
# P-value: 0.0000
# Distribution: F(328,5647)
#
# Included effects: Entity, Time
# ####### s5 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                     5.921e-05
# Estimator:                   PanelOLS   R-squared (Between):              0.3080
# No. Observations:               14968   R-squared (Within):               0.0001
# Date:                Fri, Apr 16 2021   R-squared (Overall):              0.2269
# Time:                        18:33:55   Log-likelihood                 1.552e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.4223
# Entities:                         671   P-value                           0.6555
# Avg Obs:                       22.307   Distribution:                 F(2,14265)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             0.3846
#                                         P-value                           0.6807
# Time periods:                      31   Distribution:                 F(2,14265)
# Avg Obs:                       482.84
# Min Obs:                       418.00
# Max Obs:                       660.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count    -0.0043     0.0099    -0.4326     0.6653     -0.0238      0.0152
# log_dem_count    -0.0073     0.0109    -0.6676     0.5044     -0.0287      0.0141
# =================================================================================
#
# F-test for Poolability: 16.953
# P-value: 0.0000
# Distribution: F(700,14265)
#
# Included effects: Entity, Time
# ####### s6 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0002
# Estimator:                   PanelOLS   R-squared (Between):             -0.0385
# No. Observations:                4184   R-squared (Within):               0.0003
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.0259
# Time:                        18:33:56   Log-likelihood                    4180.1
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.3967
# Entities:                         209   P-value                           0.6726
# Avg Obs:                       20.019   Distribution:                  F(2,3943)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             0.1740
#                                         P-value                           0.8403
# Time periods:                      31   Distribution:                  F(2,3943)
# Avg Obs:                       134.97
# Min Obs:                       120.00
# Max Obs:                       208.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.0179     0.0327     0.5465     0.5848     -0.0462      0.0820
# log_dem_count    -0.0057     0.0164    -0.3439     0.7309     -0.0379      0.0266
# =================================================================================
#
# F-test for Poolability: 15.279
# P-value: 0.0000
# Distribution: F(238,3943)
#
# Included effects: Entity, Time
# ####### s8 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):             -1.4581
# No. Observations:               11512   R-squared (Within):            5.472e-05
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.9959
# Time:                        18:33:56   Log-likelihood                 1.224e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.1539
# Entities:                         577   P-value                           0.1161
# Avg Obs:                       19.951   Distribution:                 F(2,10903)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             2.8714
#                                         P-value                           0.0567
# Time periods:                      31   Distribution:                 F(2,10903)
# Avg Obs:                       371.35
# Min Obs:                       299.00
# Max Obs:                       561.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.0056     0.0087     0.6518     0.5145     -0.0113      0.0226
# log_dem_count     0.0198     0.0097     2.0517     0.0402      0.0009      0.0388
# =================================================================================
#
# F-test for Poolability: 15.834
# P-value: 0.0000
# Distribution: F(606,10903)
#
# Included effects: Entity, Time

# %%
#get base models for all 7 schools
for s in schools:
    school = new[new['school'] == s]
    
    school = school.set_index(['user_id', 'period'])
    
    #rep model
    mod = PanelOLS.from_formula('emot_100_mean ~ + log_rep_count + log_dem_count + punish_law_log + racism_log + covid_log + trump_log + congress_bills_log + right_outrage_log + primaries_log + vp_nomination_log + russia_log + fed_investigation_log + arguments_log + social_media_log + healthcare_log + senate_race_log + vote_tomorrow_log + protest_log + scotus_log + institutions_log + climate_log + economy_log + vote_methods_log + progress_fight_log + covid_restrictions_log + trump_2_log + news_media_log + vp_nomination_log + social_media_log + senate_race_log + progress_fight_log + TimeEffects + EntityEffects', school)
    res = mod.fit(cov_type = 'clustered', cluster_entity = True)
    print('####### ' + s + ' ########')
    print(res)
# Out:
# ####### s1 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0478
# Estimator:                   PanelOLS   R-squared (Between):              0.4559
# No. Observations:                9779   R-squared (Within):               0.0608
# Date:                Fri, Apr 16 2021   R-squared (Overall):              0.3633
# Time:                        18:36:01   Log-likelihood                  1.03e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      17.255
# Entities:                         443   P-value                           0.0000
# Avg Obs:                       22.074   Distribution:                 F(27,9279)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             13.734
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(27,9279)
# Avg Obs:                       315.45
# Min Obs:                       262.00
# Max Obs:                       417.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.0114     0.0102     1.1151     0.2648     -0.0087      0.0315
# log_dem_count             -0.0190     0.0087    -2.1985     0.0279     -0.0360     -0.0021
# punish_law_log             0.0181     0.0029     6.1739     0.0000      0.0124      0.0239
# racism_log                 0.0153     0.0021     7.3009     0.0000      0.0112      0.0194
# covid_log                  0.0126     0.0021     6.0851     0.0000      0.0085      0.0167
# trump_log                  0.0115     0.0022     5.2414     0.0000      0.0072      0.0157
# congress_bills_log         0.0020     0.0023     0.8862     0.3755     -0.0025      0.0065
# right_outrage_log          0.0207     0.0029     7.1470     0.0000      0.0150      0.0263
# primaries_log             -0.0013     0.0024    -0.5458     0.5852     -0.0061      0.0035
# vp_nomination_log         -0.0126     0.0021    -5.9871     0.0000     -0.0167     -0.0085
# russia_log                -0.0005     0.0026    -0.1774     0.8592     -0.0056      0.0047
# fed_investigation_log      0.0099     0.0026     3.8126     0.0001      0.0048      0.0150
# arguments_log              0.0047     0.0023     2.0507     0.0403      0.0002      0.0091
# social_media_log          -0.0192     0.0023    -8.3192     0.0000     -0.0238     -0.0147
# healthcare_log             0.0046     0.0022     2.0294     0.0424      0.0002      0.0090
# senate_race_log           -0.0089     0.0021    -4.3169     0.0000     -0.0129     -0.0049
# vote_tomorrow_log         -0.0127     0.0018    -7.1535     0.0000     -0.0162     -0.0093
# protest_log                0.0189     0.0023     8.1189     0.0000      0.0143      0.0235
# scotus_log                -0.0004     0.0021    -0.1757     0.8606     -0.0046      0.0038
# institutions_log           0.0085     0.0023     3.7528     0.0002      0.0040      0.0129
# climate_log                0.0017     0.0022     0.7487     0.4541     -0.0027      0.0061
# economy_log                0.0025     0.0019     1.3055     0.1918     -0.0013      0.0063
# vote_methods_log           0.0007     0.0020     0.3577     0.7206     -0.0032      0.0046
# progress_fight_log        -0.0093     0.0023    -4.0653     0.0000     -0.0137     -0.0048
# covid_restrictions_log    -0.0048     0.0018    -2.6278     0.0086     -0.0084     -0.0012
# trump_2_log                0.0109     0.0029     3.7895     0.0002      0.0053      0.0166
# news_media_log            -0.0018     0.0024    -0.7235     0.4694     -0.0065      0.0030
# ==========================================================================================
#
# F-test for Poolability: 13.499
# P-value: 0.0000
# Distribution: F(472,9279)
#
# Included effects: Entity, Time
# ####### s2 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0548
# Estimator:                   PanelOLS   R-squared (Between):             -0.0502
# No. Observations:                1309   R-squared (Within):               0.0622
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.0407
# Time:                        18:36:01   Log-likelihood                    1422.1
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.5685
# Entities:                          57   P-value                           0.0000
# Avg Obs:                       22.965   Distribution:                 F(27,1195)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             4.8790
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(27,1195)
# Avg Obs:                       42.226
# Min Obs:                       32.000
# Max Obs:                       56.000
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.0380     0.0403     0.9428     0.3460     -0.0410      0.1170
# log_dem_count             -0.0148     0.0157    -0.9402     0.3473     -0.0456      0.0161
# punish_law_log             0.0371     0.0126     2.9417     0.0033      0.0124      0.0618
# racism_log                 0.0243     0.0081     3.0002     0.0028      0.0084      0.0401
# covid_log                  0.0045     0.0058     0.7759     0.4379     -0.0069      0.0160
# trump_log                  0.0221     0.0082     2.7131     0.0068      0.0061      0.0382
# congress_bills_log         0.0054     0.0070     0.7720     0.4402     -0.0084      0.0192
# right_outrage_log          0.0185     0.0100     1.8454     0.0652     -0.0012      0.0382
# primaries_log             -0.0100     0.0074    -1.3445     0.1790     -0.0246      0.0046
# vp_nomination_log         -0.0182     0.0067    -2.7261     0.0065     -0.0314     -0.0051
# russia_log                -0.0007     0.0151    -0.0437     0.9652     -0.0303      0.0289
# fed_investigation_log      0.0191     0.0069     2.7608     0.0059      0.0055      0.0327
# arguments_log              0.0070     0.0074     0.9375     0.3487     -0.0076      0.0215
# social_media_log          -0.0085     0.0074    -1.1477     0.2513     -0.0231      0.0060
# healthcare_log             0.0141     0.0055     2.5700     0.0103      0.0033      0.0249
# senate_race_log           -0.0184     0.0061    -3.0006     0.0028     -0.0304     -0.0064
# vote_tomorrow_log         -0.0067     0.0055    -1.2339     0.2175     -0.0175      0.0040
# protest_log                0.0206     0.0069     3.0015     0.0027      0.0071      0.0341
# scotus_log                 0.0043     0.0074     0.5884     0.5564     -0.0101      0.0188
# institutions_log          -0.0035     0.0059    -0.5996     0.5489     -0.0151      0.0080
# climate_log                0.0007     0.0059     0.1108     0.9118     -0.0109      0.0122
# economy_log                0.0061     0.0054     1.1382     0.2553     -0.0044      0.0166
# vote_methods_log           0.0024     0.0076     0.3165     0.7517     -0.0125      0.0173
# progress_fight_log        -0.0096     0.0067    -1.4418     0.1496     -0.0227      0.0035
# covid_restrictions_log    -0.0033     0.0045    -0.7328     0.4638     -0.0121      0.0055
# trump_2_log                0.0328     0.0154     2.1306     0.0333      0.0026      0.0631
# news_media_log             0.0061     0.0081     0.7498     0.4535     -0.0098      0.0219
# ==========================================================================================
#
# F-test for Poolability: 8.8272
# P-value: 0.0000
# Distribution: F(86,1195)
#
# Included effects: Entity, Time
# ####### s3 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0524
# Estimator:                   PanelOLS   R-squared (Between):              0.0357
# No. Observations:                9553   R-squared (Within):               0.0567
# Date:                Fri, Apr 16 2021   R-squared (Overall):              0.0364
# Time:                        18:36:01   Log-likelihood                    9776.6
# Cov. Estimator:             Clustered
#                                         F-statistic:                      18.522
# Entities:                         453   P-value                           0.0000
# Avg Obs:                       21.088   Distribution:                 F(27,9043)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             19.208
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(27,9043)
# Avg Obs:                       308.16
# Min Obs:                       256.00
# Max Obs:                       442.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.0210     0.0137     1.5308     0.1259     -0.0059      0.0478
# log_dem_count             -0.0072     0.0171    -0.4229     0.6724     -0.0408      0.0264
# punish_law_log             0.0125     0.0026     4.8353     0.0000      0.0074      0.0176
# racism_log                 0.0122     0.0022     5.6611     0.0000      0.0080      0.0165
# covid_log                  0.0077     0.0020     3.9642     0.0001      0.0039      0.0116
# trump_log                  0.0093     0.0021     4.3521     0.0000      0.0051      0.0134
# congress_bills_log         0.0018     0.0021     0.8440     0.3987     -0.0023      0.0058
# right_outrage_log          0.0145     0.0031     4.7249     0.0000      0.0085      0.0205
# primaries_log             -0.0013     0.0023    -0.5651     0.5720     -0.0057      0.0032
# vp_nomination_log         -0.0149     0.0019    -7.7446     0.0000     -0.0187     -0.0111
# russia_log                -0.0014     0.0029    -0.4843     0.6282     -0.0071      0.0043
# fed_investigation_log      0.0090     0.0023     4.0031     0.0001      0.0046      0.0134
# arguments_log              0.0038     0.0026     1.4455     0.1484     -0.0014      0.0089
# social_media_log          -0.0183     0.0018    -9.9219     0.0000     -0.0219     -0.0147
# healthcare_log             0.0109     0.0022     4.9744     0.0000      0.0066      0.0152
# senate_race_log           -0.0163     0.0019    -8.6097     0.0000     -0.0200     -0.0126
# vote_tomorrow_log         -0.0164     0.0018    -9.1352     0.0000     -0.0199     -0.0129
# protest_log                0.0200     0.0023     8.5466     0.0000      0.0154      0.0245
# scotus_log                -0.0033     0.0020    -1.6461     0.0998     -0.0071      0.0006
# institutions_log           0.0069     0.0021     3.2788     0.0010      0.0028      0.0110
# climate_log                0.0084     0.0021     3.9222     0.0001      0.0042      0.0126
# economy_log                0.0035     0.0020     1.7445     0.0811     -0.0004      0.0074
# vote_methods_log           0.0041     0.0019     2.1033     0.0355      0.0003      0.0079
# progress_fight_log        -0.0094     0.0020    -4.6742     0.0000     -0.0133     -0.0054
# covid_restrictions_log    -0.0050     0.0016    -3.1088     0.0019     -0.0082     -0.0018
# trump_2_log                0.0196     0.0028     7.0883     0.0000      0.0142      0.0251
# news_media_log            -0.0005     0.0022    -0.2223     0.8241     -0.0049      0.0039
# ==========================================================================================
#
# F-test for Poolability: 12.376
# P-value: 0.0000
# Distribution: F(482,9043)
#
# Included effects: Entity, Time
# ####### s4 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0464
# Estimator:                   PanelOLS   R-squared (Between):              0.0453
# No. Observations:                5978   R-squared (Within):               0.0541
# Date:                Fri, Apr 16 2021   R-squared (Overall):              0.0553
# Time:                        18:36:02   Log-likelihood                    6065.7
# Cov. Estimator:             Clustered
#                                         F-statistic:                      10.138
# Entities:                         299   P-value                           0.0000
# Avg Obs:                       19.993   Distribution:                 F(27,5622)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             10.653
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(27,5622)
# Avg Obs:                       192.84
# Min Obs:                       164.00
# Max Obs:                       292.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count             -0.0197     0.0226    -0.8712     0.3837     -0.0640      0.0246
# log_dem_count              0.0040     0.0446     0.0907     0.9278     -0.0833      0.0914
# punish_law_log             0.0139     0.0035     3.9905     0.0001      0.0071      0.0207
# racism_log                 0.0148     0.0026     5.7269     0.0000      0.0097      0.0198
# covid_log                  0.0134     0.0029     4.6195     0.0000      0.0077      0.0191
# trump_log                  0.0151     0.0034     4.4331     0.0000      0.0084      0.0218
# congress_bills_log         0.0033     0.0026     1.2485     0.2119     -0.0019      0.0084
# right_outrage_log          0.0193     0.0040     4.8147     0.0000      0.0114      0.0271
# primaries_log             -0.0007     0.0028    -0.2637     0.7920     -0.0062      0.0047
# vp_nomination_log         -0.0125     0.0023    -5.3392     0.0000     -0.0171     -0.0079
# russia_log                 0.0017     0.0039     0.4367     0.6624     -0.0059      0.0093
# fed_investigation_log      0.0096     0.0024     4.0459     0.0001      0.0050      0.0143
# arguments_log              0.0039     0.0031     1.2813     0.2001     -0.0021      0.0100
# social_media_log          -0.0178     0.0022    -7.9970     0.0000     -0.0222     -0.0135
# healthcare_log             0.0074     0.0032     2.2947     0.0218      0.0011      0.0137
# senate_race_log           -0.0163     0.0026    -6.2118     0.0000     -0.0214     -0.0111
# vote_tomorrow_log         -0.0130     0.0026    -5.0809     0.0000     -0.0181     -0.0080
# protest_log                0.0143     0.0027     5.3261     0.0000      0.0090      0.0195
# scotus_log                 0.0042     0.0027     1.5368     0.1244     -0.0012      0.0095
# institutions_log           0.0074     0.0031     2.3877     0.0170      0.0013      0.0135
# climate_log                0.0063     0.0024     2.6650     0.0077      0.0017      0.0109
# economy_log                0.0040     0.0024     1.6750     0.0940     -0.0007      0.0088
# vote_methods_log           0.0004     0.0029     0.1463     0.8837     -0.0053      0.0061
# progress_fight_log        -0.0128     0.0027    -4.8024     0.0000     -0.0180     -0.0076
# covid_restrictions_log    -0.0059     0.0025    -2.4011     0.0164     -0.0107     -0.0011
# trump_2_log                0.0127     0.0036     3.5156     0.0004      0.0056      0.0197
# news_media_log             0.0056     0.0028     1.9786     0.0479   5.132e-05      0.0111
# ==========================================================================================
#
# F-test for Poolability: 9.3517
# P-value: 0.0000
# Distribution: F(328,5622)
#
# Included effects: Entity, Time
# ####### s5 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0445
# Estimator:                   PanelOLS   R-squared (Between):              0.0843
# No. Observations:               14968   R-squared (Within):               0.0514
# Date:                Fri, Apr 16 2021   R-squared (Overall):              0.0724
# Time:                        18:36:02   Log-likelihood                 1.586e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      24.586
# Entities:                         671   P-value                           0.0000
# Avg Obs:                       22.307   Distribution:                F(27,14240)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             24.975
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                F(27,14240)
# Avg Obs:                       482.84
# Min Obs:                       418.00
# Max Obs:                       660.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count             -0.0003     0.0094    -0.0300     0.9761     -0.0188      0.0182
# log_dem_count             -0.0019     0.0104    -0.1811     0.8563     -0.0222      0.0184
# punish_law_log             0.0095     0.0017     5.5783     0.0000      0.0062      0.0128
# racism_log                 0.0158     0.0015     10.197     0.0000      0.0127      0.0188
# covid_log                  0.0072     0.0016     4.6309     0.0000      0.0042      0.0103
# trump_log                  0.0095     0.0017     5.7135     0.0000      0.0062      0.0127
# congress_bills_log        -0.0045     0.0014    -3.2150     0.0013     -0.0072     -0.0018
# right_outrage_log          0.0117     0.0017     6.7025     0.0000      0.0082      0.0151
# primaries_log             -0.0009     0.0015    -0.6089     0.5426     -0.0040      0.0021
# vp_nomination_log         -0.0139     0.0015    -8.9659     0.0000     -0.0169     -0.0108
# russia_log                 0.0006     0.0015     0.3939     0.6937     -0.0024      0.0036
# fed_investigation_log      0.0057     0.0015     3.9401     0.0001      0.0029      0.0086
# arguments_log              0.0058     0.0016     3.7099     0.0002      0.0027      0.0088
# social_media_log          -0.0147     0.0015    -9.8643     0.0000     -0.0176     -0.0118
# healthcare_log             0.0091     0.0015     6.1437     0.0000      0.0062      0.0121
# senate_race_log           -0.0102     0.0015    -6.6852     0.0000     -0.0132     -0.0072
# vote_tomorrow_log         -0.0153     0.0015    -10.546     0.0000     -0.0182     -0.0125
# protest_log                0.0152     0.0017     9.0883     0.0000      0.0120      0.0185
# scotus_log                -0.0041     0.0014    -2.9097     0.0036     -0.0069     -0.0013
# institutions_log           0.0033     0.0014     2.3200     0.0204      0.0005      0.0060
# climate_log                0.0084     0.0016     5.1895     0.0000      0.0052      0.0116
# economy_log                0.0046     0.0015     3.0532     0.0023      0.0017      0.0076
# vote_methods_log           0.0024     0.0014     1.7196     0.0855     -0.0003      0.0051
# progress_fight_log        -0.0101     0.0016    -6.3396     0.0000     -0.0133     -0.0070
# covid_restrictions_log    -0.0053     0.0014    -3.7813     0.0002     -0.0080     -0.0025
# trump_2_log                0.0151     0.0017     8.8836     0.0000      0.0118      0.0184
# news_media_log            -0.0001     0.0016    -0.0902     0.9281     -0.0032      0.0029
# ==========================================================================================
#
# F-test for Poolability: 12.934
# P-value: 0.0000
# Distribution: F(700,14240)
#
# Included effects: Entity, Time
# ####### s6 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0454
# Estimator:                   PanelOLS   R-squared (Between):             -0.1463
# No. Observations:                4184   R-squared (Within):               0.0501
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.0843
# Time:                        18:36:02   Log-likelihood                    4276.8
# Cov. Estimator:             Clustered
#                                         F-statistic:                      6.9013
# Entities:                         209   P-value                           0.0000
# Avg Obs:                       20.019   Distribution:                 F(27,3918)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             8.0703
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(27,3918)
# Avg Obs:                       134.97
# Min Obs:                       120.00
# Max Obs:                       208.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.0188     0.0306     0.6143     0.5391     -0.0412      0.0787
# log_dem_count             -0.0024     0.0161    -0.1485     0.8820     -0.0339      0.0291
# punish_law_log             0.0107     0.0046     2.3331     0.0197      0.0017      0.0198
# racism_log                 0.0168     0.0051     3.2887     0.0010      0.0068      0.0268
# covid_log                  0.0085     0.0030     2.8077     0.0050      0.0026      0.0144
# trump_log                  0.0072     0.0038     1.9207     0.0548     -0.0001      0.0146
# congress_bills_log         0.0002     0.0026     0.0722     0.9424     -0.0049      0.0053
# right_outrage_log          0.0199     0.0042     4.7140     0.0000      0.0116      0.0281
# primaries_log             -0.0030     0.0032    -0.9557     0.3393     -0.0092      0.0032
# vp_nomination_log         -0.0144     0.0034    -4.2349     0.0000     -0.0211     -0.0077
# russia_log                 0.0020     0.0042     0.4747     0.6351     -0.0062      0.0101
# fed_investigation_log      0.0102     0.0036     2.8561     0.0043      0.0032      0.0172
# arguments_log              0.0042     0.0041     1.0184     0.3086     -0.0039      0.0122
# social_media_log          -0.0146     0.0032    -4.5984     0.0000     -0.0209     -0.0084
# healthcare_log             0.0035     0.0032     1.0864     0.2774     -0.0028      0.0099
# senate_race_log           -0.0194     0.0031    -6.2916     0.0000     -0.0255     -0.0134
# vote_tomorrow_log         -0.0156     0.0033    -4.7091     0.0000     -0.0220     -0.0091
# protest_log                0.0216     0.0046     4.7201     0.0000      0.0126      0.0306
# scotus_log                -0.0055     0.0028    -1.9570     0.0504     -0.0110   9.982e-06
# institutions_log           0.0049     0.0035     1.3933     0.1636     -0.0020      0.0118
# climate_log                0.0008     0.0029     0.2665     0.7899     -0.0049      0.0064
# economy_log               -0.0011     0.0030    -0.3750     0.7077     -0.0069      0.0047
# vote_methods_log           0.0067     0.0038     1.7561     0.0792     -0.0008      0.0142
# progress_fight_log        -0.0127     0.0033    -3.8187     0.0001     -0.0192     -0.0062
# covid_restrictions_log    -0.0094     0.0034    -2.7306     0.0063     -0.0162     -0.0027
# trump_2_log                0.0145     0.0049     2.9400     0.0033      0.0048      0.0241
# news_media_log            -0.0009     0.0032    -0.2689     0.7880     -0.0072      0.0054
# ==========================================================================================
#
# F-test for Poolability: 11.752
# P-value: 0.0000
# Distribution: F(238,3918)
#
# Included effects: Entity, Time
# ####### s8 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0483
# Estimator:                   PanelOLS   R-squared (Between):             -1.0223
# No. Observations:               11512   R-squared (Within):               0.0583
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.6863
# Time:                        18:36:03   Log-likelihood                 1.252e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      20.438
# Entities:                         577   P-value                           0.0000
# Avg Obs:                       19.951   Distribution:                F(27,10878)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             19.922
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                F(27,10878)
# Avg Obs:                       371.35
# Min Obs:                       299.00
# Max Obs:                       561.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.0049     0.0084     0.5823     0.5604     -0.0116      0.0214
# log_dem_count              0.0152     0.0091     1.6699     0.0950     -0.0026      0.0330
# punish_law_log             0.0126     0.0020     6.3782     0.0000      0.0087      0.0165
# racism_log                 0.0121     0.0016     7.6966     0.0000      0.0091      0.0152
# covid_log                  0.0113     0.0018     6.3287     0.0000      0.0078      0.0148
# trump_log                  0.0083     0.0018     4.5256     0.0000      0.0047      0.0119
# congress_bills_log        -0.0011     0.0017    -0.6649     0.5061     -0.0044      0.0021
# right_outrage_log          0.0177     0.0021     8.3545     0.0000      0.0135      0.0218
# primaries_log             -0.0014     0.0017    -0.8100     0.4179     -0.0047      0.0020
# vp_nomination_log         -0.0145     0.0017    -8.7872     0.0000     -0.0178     -0.0113
# russia_log                 0.0016     0.0017     0.9482     0.3430     -0.0017      0.0049
# fed_investigation_log      0.0060     0.0016     3.7620     0.0002      0.0029      0.0092
# arguments_log              0.0050     0.0018     2.8398     0.0045      0.0016      0.0085
# social_media_log          -0.0146     0.0017    -8.3260     0.0000     -0.0180     -0.0111
# healthcare_log             0.0044     0.0018     2.5247     0.0116      0.0010      0.0079
# senate_race_log           -0.0137     0.0016    -8.6033     0.0000     -0.0168     -0.0106
# vote_tomorrow_log         -0.0156     0.0016    -9.5121     0.0000     -0.0188     -0.0124
# protest_log                0.0188     0.0017     10.963     0.0000      0.0154      0.0221
# scotus_log                -0.0026     0.0016    -1.6148     0.1064     -0.0058      0.0006
# institutions_log           0.0031     0.0017     1.8361     0.0664     -0.0002      0.0064
# climate_log                0.0026     0.0017     1.5832     0.1134     -0.0006      0.0059
# economy_log                0.0048     0.0016     3.0840     0.0020      0.0018      0.0079
# vote_methods_log          -0.0016     0.0016    -1.0412     0.2978     -0.0047      0.0014
# progress_fight_log        -0.0095     0.0020    -4.6908     0.0000     -0.0135     -0.0055
# covid_restrictions_log    -0.0067     0.0016    -4.2470     0.0000     -0.0098     -0.0036
# trump_2_log                0.0083     0.0020     4.0604     0.0000      0.0043      0.0123
# news_media_log             0.0008     0.0018     0.4438     0.6572     -0.0027      0.0043
# ==========================================================================================
#
# F-test for Poolability: 12.410
# P-value: 0.0000
# Distribution: F(606,10878)
#
# Included effects: Entity, Time
