# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from linearmodels import PanelOLS
from sklearn.decomposition import PCA

# %%
#read in most recent final product
df = pd.read_csv('/home/twalton_umass_edu/Political Polarization Project/final/final_product_topic_45_20210427.csv')

#list of schools to loop through
schools = ['s1', 's2', 's3', 's4', 's5', 's6', 's8']

#only want republicans
df = df[df['rep_org'] == 1]

#number of data points
print('total original data points: ' + str(len(df)))
      
#get rid of first three period due to missing ties
df = df[(df['period'] >= 4)]

df = df.groupby(['user_id', 'school']).filter(lambda x: len(x) > 25)
    
#fill in nans with 0
df = df.fillna(0)
      
#create new variable that is the variance of the rep count for each user_id/school pair
df = df.join(df.groupby(['user_id', 'school'])['rep_count'].var(), on = ['user_id', 'school'], rsuffix = '_var')

#create new variable that is the variance of the dem_coutn for each user_id/school pair
df = df.join(df.groupby(['user_id', 'school'])['dem_count'].var(), on = ['user_id', 'school'], rsuffix = '_var')

#create a new variable that is the total number of tweets for the individual
df = df.join(df.groupby(['user_id', 'school'])['num_tweets'].sum(), on = ['user_id', 'school'], rsuffix = '_sum')

#keep usee that have at least both variance or at least one tweet
df = df[(df['num_tweets_sum'] != 0) | ((df['dem_count_var'] != 0) & (df['rep_count_var'] != 0))]

      
topics = {'X0': 'news_media', 'X1': 'location', 'X2': 'numerics', 'X3': 'contractions', 'X4': 'names'
         ,'X5': 'religion', 'X6': 'derogatory_media', 'X7': 'covid_restrictions', 'X8': 'innovate'
         ,'X9': 'republicans', 'X10': 'economics', 'X11': 'family', 'X12': 'police_violence', 'X13': 'date_time'
         ,'X14': 'argument', 'X15': 'fed_investigation', 'X16': 'spam', 'X17': 'covid', 'X18': 'misc'
         ,'X19': 'law_constituion', 'X20': 'riot', 'X21': 'scotus', 'X22': 'outdoors', 'X23': 'sports'
         ,'X24': 'racism', 'X25': 'voting', 'X26': 'ideology', 'X27': 'movement', 'X28': 'social_media'
         ,'X29': 'democracy_future', 'X30': 'holiday', 'X31': 'possiblity', 'X32': 'awesom', 'X33': 'prayer'
         ,'X34': 'social_media_derogatory', 'X35': 'foreign_enemies', 'X36': 'small_talk', 'X37': 'election'
         ,'X38': 'calendar_day', 'X39': 'globalism', 'X40': 'food', 'X41': 'random _objects', 'X42': 'biden_campaign'
         ,'X43': 'yeah', 'X44': 'sexual_violence', 'X45': 'no_topic'}
      
#rename topic variables
df = df.rename(columns = topics)

df['log_dem_count'] = np.log(df['dem_count'] + 1)
df['log_rep_count'] = np.log(df['rep_count'] + 1)
df['log_tot_pol'] = np.log(df['rep_count'] + df['dem_count'] + 1)
df['log_total_count'] = np.log(df['total_count'] + 1)
df['log_num_tweets'] = np.log(df['num_tweets'] + 1)
df['norm_emot_50'] = (df['emot_50_mean'] - df['emot_50_mean'].mean()) / df['emot_50_mean'].std()
df['norm_emot_100'] = (df['emot_100_mean'] - df['emot_100_mean'].mean()) / df['emot_100_mean'].std()
df['norm_emot_150'] = (df['emot_150_mean'] - df['emot_150_mean'].mean()) / df['emot_150_mean'].std()
df['norm_emot_200'] = (df['emot_200_mean'] - df['emot_200_mean'].mean()) / df['emot_200_mean'].std()

df['news_media_log'] = np.log(df['news_media'] + 1)
df['covid_restrictions_log'] = np.log(df['covid_restrictions'] + 1)
df['republicans_log'] = np.log(df['republicans']+1)
df['economics_log'] = np.log(df['economics']+1)
df['police_violence_log'] = np.log(df['police_violence']+1)
df['argument_log'] = np.log(df['argument']+1)
df['fed_investigation_log'] = np.log(df['fed_investigation']+1)
df['law_constitution_log'] = np.log(df['law_constituion']+1)
df['racism_log'] = np.log(df['racism']+1)
df['voting_log'] = np.log(df['voting']+1)
df['ideology_log'] = np.log(df['ideology']+1)
df['social_media_log'] = np.log(df['social_media'] + 1)
df['democracy_future_log'] = np.log(df['democracy_future'] + 1)
df['riot_log'] = np.log(df['riot'] + 1)
df['covid_log'] = np.log(df['covid'] + 1)
df['scotus_log'] = np.log(df['scotus'] + 1)
df['police_violence_log'] = np.log(df['police_violence'] + 1)
df['derogatory_media_log'] = np.log(df['derogatory_media'] + 1)
df['social_media_derogatory_log'] = np.log(df['social_media_derogatory'] + 1)
df['foreign_enemies_log'] = np.log(df['foreign_enemies'] + 1)
df['election_log'] = np.log(df['election'] + 1)
df['globalism_log'] = np.log(df['globalism'] + 1)
df['biden_campaign_log'] = np.log(df['biden_campaign'] + 1)
df['innovate_log'] = np.log(df['innovate'] + 1)
df['news_media_log'] = np.log(df['news_media'] + 1)
df['numbers_log'] = np.log(df['numbers'] + 1)
df['names_log'] = np.log(df['names'] + 1)
df['location_log'] = np.log(df['location'] + 1)
df['argument_log'] = np.log(df['argument'] + 1)
df['awesome_log'] = np.log(df['awesome'] + 1)
df['sexual_violence_log'] = np.log(df['sexual_violence'] + 1)

# %%
print(len(df))
# Out:
# 111360

# %%
#get rep change variable
df.sort_values(['user_id', 'period'], inplace=True)
df['rep_change'] = df.groupby(['user_id', 'school'])['rep_count'].diff()

#get dem change variable
df.sort_values(['user_id', 'period'], inplace=True)
df['dem_change'] = df.groupby(['user_id', 'school'])['dem_count'].diff()

# %%
#individuals that have at least one change
new = df.loc[(df['rep_change'] != 0) | (df['dem_change'] != 0) | (df['num_tweets'] != 0)]

# %%
#at least one tweet
new2 = df.loc[df['emot_100_mean'] != 0]

# %%
print(len(new))
print(len(new2))
# Out:
# 80355
# 74420

# %%
new2.to_csv('/home/twalton_umass_edu/Political Polarization Project/rep_20210428.csv')

# %%
#get base models for all 7 schools
for s in schools:
    school = new2[new2['school'] == s]
    
    school = school.set_index(['user_id', 'period'])
    
    #rep model
    mod = PanelOLS.from_formula('norm_emot_100 ~ + log_rep_count + log_dem_count + TimeEffects + EntityEffects', school)
    res = mod.fit(cov_type = 'clustered', cluster_entity = True)
    print('####### ' + s + ' ########')
    print(res)
# Out:
# ####### s1 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0024
# Estimator:                   PanelOLS   R-squared (Between):             -1.6611
# No. Observations:                4763   R-squared (Within):               0.0012
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -1.3368
# Time:                        13:20:57   Log-likelihood                   -6526.2
# Cov. Estimator:             Clustered
#                                         F-statistic:                      5.5170
# Entities:                         233   P-value                           0.0040
# Avg Obs:                       20.442   Distribution:                  F(2,4498)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             2.9323
#                                         P-value                           0.0534
# Time periods:                      31   Distribution:                  F(2,4498)
# Avg Obs:                       153.65
# Min Obs:                       99.000
# Max Obs:                       177.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.2767     0.1476     1.8746     0.0609     -0.0127      0.5661
# log_dem_count     0.0937     0.1427     0.6569     0.5113     -0.1860      0.3735
# =================================================================================
#
# F-test for Poolability: 20.884
# P-value: 0.0000
# Distribution: F(262,4498)
#
# Included effects: Entity, Time
# ####### s2 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0005
# Estimator:                   PanelOLS   R-squared (Between):             -0.6968
# No. Observations:                3005   R-squared (Within):              -0.0001
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.5551
# Time:                        13:20:58   Log-likelihood                   -3899.2
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.7470
# Entities:                         147   P-value                           0.4739
# Avg Obs:                       20.442   Distribution:                  F(2,2826)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             0.5698
#                                         P-value                           0.5657
# Time periods:                      31   Distribution:                  F(2,2826)
# Avg Obs:                       96.935
# Min Obs:                       76.000
# Max Obs:                       109.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.2717     0.3068     0.8855     0.3760     -0.3299      0.8733
# log_dem_count    -0.1756     0.2765    -0.6351     0.5254     -0.7178      0.3666
# =================================================================================
#
# F-test for Poolability: 16.200
# P-value: 0.0000
# Distribution: F(176,2826)
#
# Included effects: Entity, Time
# ####### s3 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0005
# Estimator:                   PanelOLS   R-squared (Between):             -0.2302
# No. Observations:               14487   R-squared (Within):               0.0018
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.2413
# Time:                        13:20:58   Log-likelihood                -1.494e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3.3431
# Entities:                         618   P-value                           0.0354
# Avg Obs:                       23.442   Distribution:                 F(2,13837)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             3.5972
#                                         P-value                           0.0274
# Time periods:                      31   Distribution:                 F(2,13837)
# Avg Obs:                       467.32
# Min Obs:                       354.00
# Max Obs:                       499.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count    -0.1128     0.0803    -1.4049     0.1601     -0.2702      0.0446
# log_dem_count     0.1265     0.0485     2.6100     0.0091      0.0315      0.2215
# =================================================================================
#
# F-test for Poolability: 27.363
# P-value: 0.0000
# Distribution: F(647,13837)
#
# Included effects: Entity, Time
# ####### s4 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0012
# Estimator:                   PanelOLS   R-squared (Between):             -0.2119
# No. Observations:                2697   R-squared (Within):               0.0017
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.2541
# Time:                        13:20:58   Log-likelihood                   -3007.9
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.4819
# Entities:                         133   P-value                           0.2274
# Avg Obs:                       20.278   Distribution:                  F(2,2532)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             1.7536
#                                         P-value                           0.1734
# Time periods:                      31   Distribution:                  F(2,2532)
# Avg Obs:                       87.000
# Min Obs:                       72.000
# Max Obs:                       101.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count    -0.1894     0.1999    -0.9478     0.3433     -0.5814      0.2025
# log_dem_count     0.3315     0.1771     1.8717     0.0614     -0.0158      0.6787
# =================================================================================
#
# F-test for Poolability: 22.962
# P-value: 0.0000
# Distribution: F(162,2532)
#
# Included effects: Entity, Time
# ####### s5 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0003
# Estimator:                   PanelOLS   R-squared (Between):             -0.1890
# No. Observations:               24837   R-squared (Within):               0.0009
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.1945
# Time:                        13:20:59   Log-likelihood                -2.758e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3.4445
# Entities:                        1106   P-value                           0.0319
# Avg Obs:                       22.457   Distribution:                 F(2,23699)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             1.5923
#                                         P-value                           0.2035
# Time periods:                      31   Distribution:                 F(2,23699)
# Avg Obs:                       801.19
# Min Obs:                       672.00
# Max Obs:                       872.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count    -0.1221     0.1079    -1.1316     0.2578     -0.3335      0.0894
# log_dem_count     0.1307     0.0789     1.6565     0.0976     -0.0239      0.2853
# =================================================================================
#
# F-test for Poolability: 20.403
# P-value: 0.0000
# Distribution: F(1135,23699)
#
# Included effects: Entity, Time
# ####### s6 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0012
# Estimator:                   PanelOLS   R-squared (Between):             -1.7469
# No. Observations:                4700   R-squared (Within):               0.0009
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -1.4902
# Time:                        13:20:59   Log-likelihood                   -6392.0
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.5690
# Entities:                         249   P-value                           0.0767
# Avg Obs:                       18.876   Distribution:                  F(2,4419)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             3.7320
#                                         P-value                           0.0240
# Time periods:                      31   Distribution:                  F(2,4419)
# Avg Obs:                       151.61
# Min Obs:                       131.00
# Max Obs:                       163.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.2935     0.1187     2.4725     0.0135      0.0608      0.5263
# log_dem_count     0.0699     0.1530     0.4571     0.6476     -0.2301      0.3700
# =================================================================================
#
# F-test for Poolability: 11.415
# P-value: 0.0000
# Distribution: F(278,4419)
#
# Included effects: Entity, Time
# ####### s8 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):             -0.5834
# No. Observations:               19931   R-squared (Within):              -0.0002
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.3957
# Time:                        13:20:59   Log-likelihood                -2.368e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      4.2275
# Entities:                         996   P-value                           0.0146
# Avg Obs:                       20.011   Distribution:                 F(2,18903)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             2.9697
#                                         P-value                           0.0513
# Time periods:                      31   Distribution:                 F(2,18903)
# Avg Obs:                       642.94
# Min Obs:                       497.00
# Max Obs:                       714.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.1049     0.0628     1.6693     0.0951     -0.0183      0.2280
# log_dem_count     0.0959     0.0769     1.2472     0.2123     -0.0548      0.2466
# =================================================================================
#
# F-test for Poolability: 20.280
# P-value: 0.0000
# Distribution: F(1025,18903)
#
# Included effects: Entity, Time

# %%
#get base models for all 7 schools
for s in schools:
    school = new2[new2['school'] == s]
    
    school = school.set_index(['user_id', 'period'])
    
    #rep model
    mod = PanelOLS.from_formula('norm_emot_100 ~ + log_rep_count + log_dem_count + covid_restrictions_log + economics_log + argument_log + fed_investigation_log + law_constitution_log + racism_log + voting_log + ideology_log + riot_log + covid_log + police_violence_log + derogatory_media_log + foreign_enemies_log + globalism_log + TimeEffects + EntityEffects', school)
    res = mod.fit(cov_type = 'clustered', cluster_entity = True)
    print('####### ' + s + ' ########')
    print(res)
# Out:
# ####### s1 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0194
# Estimator:                   PanelOLS   R-squared (Between):             -1.7551
# No. Observations:                4763   R-squared (Within):               0.0222
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -1.4452
# Time:                        13:21:49   Log-likelihood                   -6485.4
# Cov. Estimator:             Clustered
#                                         F-statistic:                      5.5470
# Entities:                         233   P-value                           0.0000
# Avg Obs:                       20.442   Distribution:                 F(16,4484)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             5.3895
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(16,4484)
# Avg Obs:                       153.65
# Min Obs:                       99.000
# Max Obs:                       177.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.2622     0.1414     1.8550     0.0637     -0.0149      0.5394
# log_dem_count              0.1033     0.1325     0.7796     0.4357     -0.1565      0.3631
# covid_restrictions_log     0.0220     0.0280     0.7859     0.4319     -0.0329      0.0769
# economics_log             -0.0162     0.0294    -0.5520     0.5810     -0.0738      0.0414
# argument_log               0.1136     0.0312     3.6377     0.0003      0.0524      0.1749
# fed_investigation_log     -0.1157     0.0426    -2.7151     0.0067     -0.1992     -0.0322
# law_constitution_log       0.0842     0.0305     2.7607     0.0058      0.0244      0.1440
# racism_log                -0.0067     0.0331    -0.2015     0.8403     -0.0715      0.0582
# voting_log                -0.0871     0.0292    -2.9883     0.0028     -0.1443     -0.0300
# ideology_log               0.0468     0.0278     1.6829     0.0925     -0.0077      0.1012
# riot_log                   0.0819     0.0375     2.1806     0.0293      0.0083      0.1555
# covid_log                  0.0594     0.0259     2.2878     0.0222      0.0085      0.1102
# police_violence_log       -0.0135     0.0315    -0.4284     0.6684     -0.0753      0.0483
# derogatory_media_log      -0.0139     0.0301    -0.4616     0.6444     -0.0728      0.0451
# foreign_enemies_log       -0.0384     0.0302    -1.2695     0.2043     -0.0976      0.0209
# globalism_log              0.1741     0.0376     4.6310     0.0000      0.1004      0.2478
# ==========================================================================================
#
# F-test for Poolability: 16.363
# P-value: 0.0000
# Distribution: F(262,4484)
#
# Included effects: Entity, Time
# ####### s2 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0183
# Estimator:                   PanelOLS   R-squared (Between):             -0.8705
# No. Observations:                3005   R-squared (Within):               0.0243
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.7376
# Time:                        13:21:50   Log-likelihood                   -3872.3
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3.2745
# Entities:                         147   P-value                           0.0000
# Avg Obs:                       20.442   Distribution:                 F(16,2812)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             4.6524
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(16,2812)
# Avg Obs:                       96.935
# Min Obs:                       76.000
# Max Obs:                       109.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.2754     0.2903     0.9487     0.3428     -0.2938      0.8446
# log_dem_count             -0.1671     0.2579    -0.6480     0.5171     -0.6727      0.3385
# covid_restrictions_log     0.0872     0.0314     2.7775     0.0055      0.0256      0.1487
# economics_log              0.0222     0.0332     0.6702     0.5028     -0.0428      0.0873
# argument_log               0.0642     0.0332     1.9336     0.0533     -0.0009      0.1294
# fed_investigation_log     -0.0953     0.0304    -3.1354     0.0017     -0.1549     -0.0357
# law_constitution_log       0.0458     0.0289     1.5821     0.1137     -0.0110      0.1025
# racism_log                -0.0290     0.0324    -0.8946     0.3711     -0.0926      0.0346
# voting_log                -0.1322     0.0347    -3.8165     0.0001     -0.2002     -0.0643
# ideology_log               0.1034     0.0297     3.4838     0.0005      0.0452      0.1616
# riot_log                   0.0668     0.0323     2.0658     0.0389      0.0034      0.1302
# covid_log                  0.0317     0.0266     1.1907     0.2339     -0.0205      0.0839
# police_violence_log        0.0043     0.0437     0.0974     0.9224     -0.0814      0.0899
# derogatory_media_log      -0.0471     0.0367    -1.2824     0.1998     -0.1192      0.0249
# foreign_enemies_log       -0.0522     0.0318    -1.6417     0.1008     -0.1146      0.0102
# globalism_log              0.1265     0.0371     3.4096     0.0007      0.0538      0.1993
# ==========================================================================================
#
# F-test for Poolability: 12.742
# P-value: 0.0000
# Distribution: F(176,2812)
#
# Included effects: Entity, Time
# ####### s3 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0191
# Estimator:                   PanelOLS   R-squared (Between):             -0.0410
# No. Observations:               14487   R-squared (Within):               0.0416
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.0454
# Time:                        13:21:50   Log-likelihood                -1.481e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      16.841
# Entities:                         618   P-value                           0.0000
# Avg Obs:                       23.442   Distribution:                F(16,13823)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             20.738
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                F(16,13823)
# Avg Obs:                       467.32
# Min Obs:                       354.00
# Max Obs:                       499.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count             -0.1029     0.0850    -1.2109     0.2260     -0.2695      0.0637
# log_dem_count              0.1004     0.0442     2.2714     0.0231      0.0138      0.1870
# covid_restrictions_log    -0.0020     0.0098    -0.2021     0.8399     -0.0212      0.0172
# economics_log             -0.0593     0.0104    -5.7273     0.0000     -0.0796     -0.0390
# argument_log               0.0447     0.0117     3.8298     0.0001      0.0218      0.0675
# fed_investigation_log     -0.0474     0.0089    -5.3186     0.0000     -0.0648     -0.0299
# law_constitution_log      -0.0015     0.0101    -0.1476     0.8826     -0.0214      0.0184
# racism_log                 0.0228     0.0100     2.2706     0.0232      0.0031      0.0424
# voting_log                -0.0729     0.0092    -7.9470     0.0000     -0.0909     -0.0549
# ideology_log               0.0256     0.0113     2.2723     0.0231      0.0035      0.0478
# riot_log                   0.0571     0.0098     5.8364     0.0000      0.0379      0.0762
# covid_log                  0.0014     0.0092     0.1531     0.8784     -0.0167      0.0195
# police_violence_log        0.0589     0.0099     5.9333     0.0000      0.0394      0.0783
# derogatory_media_log      -0.0037     0.0096    -0.3891     0.6972     -0.0226      0.0151
# foreign_enemies_log       -0.0576     0.0098    -5.8515     0.0000     -0.0768     -0.0383
# globalism_log              0.0984     0.0113     8.7079     0.0000      0.0763      0.1206
# ==========================================================================================
#
# F-test for Poolability: 21.303
# P-value: 0.0000
# Distribution: F(647,13823)
#
# Included effects: Entity, Time
# ####### s4 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0156
# Estimator:                   PanelOLS   R-squared (Between):             -0.0381
# No. Observations:                2697   R-squared (Within):               0.0227
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.0808
# Time:                        13:21:50   Log-likelihood                   -2988.3
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.4981
# Entities:                         133   P-value                           0.0008
# Avg Obs:                       20.278   Distribution:                 F(16,2518)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             6.1492
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(16,2518)
# Avg Obs:                       87.000
# Min Obs:                       72.000
# Max Obs:                       101.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count             -0.2461     0.2001    -1.2299     0.2188     -0.6386      0.1463
# log_dem_count              0.3013     0.1712     1.7602     0.0785     -0.0343      0.6370
# covid_restrictions_log     0.0126     0.0244     0.5175     0.6048     -0.0352      0.0604
# economics_log             -0.0554     0.0266    -2.0808     0.0376     -0.1076     -0.0032
# argument_log               0.0267     0.0351     0.7591     0.4479     -0.0422      0.0955
# fed_investigation_log     -0.0344     0.0219    -1.5704     0.1165     -0.0773      0.0086
# law_constitution_log       0.0056     0.0305     0.1855     0.8528     -0.0541      0.0654
# racism_log                 0.0301     0.0247     1.2215     0.2220     -0.0182      0.0785
# voting_log                -0.0724     0.0212    -3.4128     0.0007     -0.1140     -0.0308
# ideology_log              -0.0177     0.0304    -0.5801     0.5619     -0.0774      0.0420
# riot_log                   0.0339     0.0275     1.2350     0.2169     -0.0199      0.0878
# covid_log                  0.1227     0.0350     3.5042     0.0005      0.0540      0.1913
# police_violence_log        0.0416     0.0256     1.6263     0.1040     -0.0086      0.0918
# derogatory_media_log      -0.0067     0.0267    -0.2500     0.8026     -0.0591      0.0458
# foreign_enemies_log       -0.0245     0.0260    -0.9418     0.3464     -0.0754      0.0265
# globalism_log              0.0888     0.0307     2.8900     0.0039      0.0286      0.1491
# ==========================================================================================
#
# F-test for Poolability: 17.164
# P-value: 0.0000
# Distribution: F(162,2518)
#
# Included effects: Entity, Time
# ####### s5 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0178
# Estimator:                   PanelOLS   R-squared (Between):             -0.0551
# No. Observations:               24837   R-squared (Within):               0.0329
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.0633
# Time:                        13:21:51   Log-likelihood                -2.736e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      26.789
# Entities:                        1106   P-value                           0.0000
# Avg Obs:                       22.457   Distribution:                F(16,23685)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             32.927
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                F(16,23685)
# Avg Obs:                       801.19
# Min Obs:                       672.00
# Max Obs:                       872.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count             -0.1282     0.1020    -1.2573     0.2086     -0.3280      0.0716
# log_dem_count              0.1110     0.0772     1.4389     0.1502     -0.0402      0.2623
# covid_restrictions_log     0.0060     0.0079     0.7605     0.4469     -0.0095      0.0215
# economics_log             -0.0540     0.0078    -6.9246     0.0000     -0.0692     -0.0387
# argument_log               0.0356     0.0092     3.8724     0.0001      0.0176      0.0537
# fed_investigation_log     -0.0533     0.0079    -6.7228     0.0000     -0.0688     -0.0378
# law_constitution_log      -0.0035     0.0082    -0.4282     0.6685     -0.0195      0.0125
# racism_log                 0.0047     0.0079     0.5999     0.5486     -0.0107      0.0202
# voting_log                -0.0704     0.0078    -9.0878     0.0000     -0.0856     -0.0553
# ideology_log               0.0242     0.0089     2.7110     0.0067      0.0067      0.0416
# riot_log                   0.0625     0.0082     7.6046     0.0000      0.0464      0.0786
# covid_log                  0.0415     0.0076     5.4442     0.0000      0.0266      0.0565
# police_violence_log        0.0698     0.0086     8.0993     0.0000      0.0529      0.0867
# derogatory_media_log       0.0097     0.0081     1.1975     0.2311     -0.0062      0.0255
# foreign_enemies_log       -0.0489     0.0077    -6.3163     0.0000     -0.0640     -0.0337
# globalism_log              0.0976     0.0093     10.500     0.0000      0.0794      0.1159
# ==========================================================================================
#
# F-test for Poolability: 16.788
# P-value: 0.0000
# Distribution: F(1135,23685)
#
# Included effects: Entity, Time
# ####### s6 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0164
# Estimator:                   PanelOLS   R-squared (Between):             -1.5675
# No. Observations:                4700   R-squared (Within):               0.0183
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -1.3788
# Time:                        13:21:51   Log-likelihood                   -6355.8
# Cov. Estimator:             Clustered
#                                         F-statistic:                      4.6041
# Entities:                         249   P-value                           0.0000
# Avg Obs:                       18.876   Distribution:                 F(16,4405)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             6.3421
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(16,4405)
# Avg Obs:                       151.61
# Min Obs:                       131.00
# Max Obs:                       163.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.2583     0.1165     2.2175     0.0266      0.0299      0.4868
# log_dem_count              0.0651     0.1492     0.4360     0.6629     -0.2275      0.3576
# covid_restrictions_log     0.0369     0.0277     1.3307     0.1833     -0.0175      0.0913
# economics_log             -0.0399     0.0283    -1.4129     0.1578     -0.0953      0.0155
# argument_log               0.1121     0.0303     3.6949     0.0002      0.0526      0.1716
# fed_investigation_log     -0.1311     0.0315    -4.1691     0.0000     -0.1928     -0.0695
# law_constitution_log       0.0679     0.0326     2.0853     0.0371      0.0041      0.1318
# racism_log                -0.0728     0.0403    -1.8058     0.0710     -0.1518      0.0062
# voting_log                -0.1058     0.0319    -3.3177     0.0009     -0.1683     -0.0433
# ideology_log              -0.0036     0.0283    -0.1258     0.8999     -0.0590      0.0519
# riot_log                   0.0714     0.0321     2.2261     0.0261      0.0085      0.1343
# covid_log                  0.1444     0.0285     5.0739     0.0000      0.0886      0.2002
# police_violence_log        0.0476     0.0332     1.4356     0.1512     -0.0174      0.1126
# derogatory_media_log      -0.0155     0.0390    -0.3962     0.6919     -0.0920      0.0610
# foreign_enemies_log       -0.0693     0.0344    -2.0162     0.0438     -0.1367     -0.0019
# globalism_log              0.1560     0.0416     3.7474     0.0002      0.0744      0.2376
# ==========================================================================================
#
# F-test for Poolability: 9.6860
# P-value: 0.0000
# Distribution: F(278,4405)
#
# Included effects: Entity, Time
# ####### s8 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          norm_emot_100   R-squared:                        0.0155
# Estimator:                   PanelOLS   R-squared (Between):             -0.5196
# No. Observations:               19931   R-squared (Within):               0.0259
# Date:                Wed, Apr 28 2021   R-squared (Overall):             -0.3698
# Time:                        13:21:52   Log-likelihood                -2.352e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      18.591
# Entities:                         996   P-value                           0.0000
# Avg Obs:                       20.011   Distribution:                F(16,18889)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             22.732
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                F(16,18889)
# Avg Obs:                       642.94
# Min Obs:                       497.00
# Max Obs:                       714.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.0835     0.0636     1.3133     0.1891     -0.0411      0.2082
# log_dem_count              0.0911     0.0776     1.1738     0.2405     -0.0610      0.2433
# covid_restrictions_log    -0.0021     0.0094    -0.2266     0.8208     -0.0205      0.0162
# economics_log             -0.0346     0.0098    -3.5490     0.0004     -0.0537     -0.0155
# argument_log               0.0650     0.0121     5.3779     0.0000      0.0413      0.0887
# fed_investigation_log     -0.0557     0.0102    -5.4861     0.0000     -0.0756     -0.0358
# law_constitution_log       0.0018     0.0111     0.1617     0.8715     -0.0200      0.0236
# racism_log                 0.0069     0.0101     0.6827     0.4948     -0.0128      0.0266
# voting_log                -0.0585     0.0104    -5.6141     0.0000     -0.0790     -0.0381
# ideology_log               0.0262     0.0102     2.5603     0.0105      0.0061      0.0463
# riot_log                   0.0646     0.0098     6.5827     0.0000      0.0454      0.0839
# covid_log                  0.0371     0.0094     3.9438     0.0001      0.0187      0.0556
# police_violence_log        0.0478     0.0097     4.9482     0.0000      0.0289      0.0668
# derogatory_media_log      -0.0044     0.0107    -0.4083     0.6831     -0.0254      0.0167
# foreign_enemies_log       -0.0548     0.0102    -5.3802     0.0000     -0.0748     -0.0348
# globalism_log              0.1087     0.0121     8.9856     0.0000      0.0850      0.1324
# ==========================================================================================
#
# F-test for Poolability: 17.135
# P-value: 0.0000
# Distribution: F(1025,18889)
#
# Included effects: Entity, Time

# %%
#read in most recent final product
df = pd.read_csv('/home/twalton_umass_edu/Political Polarization Project/final/final_product_20210402.csv')

#list of schools to loop through
schools = ['s1', 's2', 's3', 's4', 's5', 's6', 's8']

#only want republicans
df = df[df['rep_org'] == 1]

#number of data points
print('total original data points: ' + str(len(df)))
      
#get rid of first three period due to missing ties
df = df[(df['period'] >= 4)]

df = df.groupby(['user_id', 'school']).filter(lambda x: len(x) > 25)
    
#fill in nans with 0
df = df.fillna(0)
      
#create new variable that is the variance of the rep count for each user_id/school pair
df = df.join(df.groupby(['user_id', 'school'])['rep_count'].var(), on = ['user_id', 'school'], rsuffix = '_var')

#create new variable that is the variance of the dem_coutn for each user_id/school pair
df = df.join(df.groupby(['user_id', 'school'])['dem_count'].var(), on = ['user_id', 'school'], rsuffix = '_var')

#create a new variable that is the total number of tweets for the individual
df = df.join(df.groupby(['user_id', 'school'])['num_tweets'].sum(), on = ['user_id', 'school'], rsuffix = '_sum')

#keep usee that have at least both variance or at least one tweet
df = df[(df['num_tweets_sum'] != 0) | ((df['dem_count_var'] != 0) & (df['rep_count_var'] != 0))]

      
topics = {'X0': 'news_media', 'X1': 'location', 'X2': 'numerics', 'X3': 'contractions', 'X4': 'names'
         ,'X5': 'religion', 'X6': 'derogatory_media', 'X7': 'covid_restrictions', 'X8': 'innovate'
         ,'X9': 'republicans', 'X10': 'economics', 'X11': 'family', 'X12': 'police_violence', 'X13': 'date_time'
         ,'X14': 'argument', 'X15': 'fed_investigation', 'X16': 'spam', 'X17': 'covid', 'X18': 'misc'
         ,'X19': 'law_constituion', 'X20': 'riot', 'X21': 'scotus', 'X22': 'outdoors', 'X23': 'sports'
         ,'X24': 'racism', 'X25': 'voting', 'X26': 'ideology', 'X27': 'movement', 'X28': 'social_media'
         ,'X29': 'democracy_future', 'X30': 'holiday', 'X31': 'possiblity', 'X32': 'awesom', 'X33': 'prayer'
         ,'X34': 'social_media_derogatory', 'X35': 'foreign_enemies', 'X36': 'small_talk', 'X37': 'election'
         ,'X38': 'calendar_day', 'X39': 'globalism', 'X40': 'food', 'X41': 'random _objects', 'X42': 'biden_campaign'
         ,'X43': 'yeah', 'X44': 'sexual_violence', 'X45': 'no_topic'}
      
#rename topic variables
df = df.rename(columns = topics)

df['log_dem_count'] = np.log(df['dem_count'] + 1)
df['log_rep_count'] = np.log(df['rep_count'] + 1)
df['log_tot_pol'] = np.log(df['rep_count'] + df['dem_count'] + 1)
df['log_total_count'] = np.log(df['total_count'] + 1)
df['log_num_tweets'] = np.log(df['num_tweets'] + 1)
df['norm_emot_50'] = (df['emot_50_mean'] - df['emot_50_mean'].mean()) / df['emot_50_mean'].std()
df['norm_emot_100'] = (df['emot_100_mean'] - df['emot_100_mean'].mean()) / df['emot_100_mean'].std()
df['norm_emot_150'] = (df['emot_150_mean'] - df['emot_150_mean'].mean()) / df['emot_150_mean'].std()
df['norm_emot_200'] = (df['emot_200_mean'] - df['emot_200_mean'].mean()) / df['emot_200_mean'].std()

df['news_media_log'] = np.log(df['news_media'] + 1)
df['covid_restrictions_log'] = np.log(df['covid_restrictions'] + 1)
df['republicnas_log'] = np.log(df['republicans']+1)
df['economics_log'] = np.log(df['economics']+1)
df['police_violence_log'] = np.log(df['police_violence']+1)
df['argument_log'] = np.log(df['argument']+1)
df['fed_investigation_log'] = np.log(df['fed_investigation']+1)
df['law_constitution_log'] = np.log(df['law_constituion']+1)
df['racism_log'] = np.log(df['racism']+1)
df['voting_log'] = np.log(df['voting']+1)
df['ideology_log'] = np.log(df['ideology']+1)
df['social_media_log'] = np.log(df['social_media'] + 1)
df['democracy_future_log'] = np.log(df['democracy_future'] + 1)
df['riot_log'] = np.log(df['riot'] + 1)
df['covid_log'] = np.log(df['covid'] + 1)
df['scotus_log'] = np.log(df['scotus'] + 1)
df['police_violence_log'] = np.log(df['police_violence'] + 1)
df['derogatory_media_log'] = np.log(df['derogatory_media'] + 1)
df['social_media_derogatory_log'] = np.log(df['social_media_derogatory'] + 1)
df['foreign_enemies_log'] = np.log(df['foreign_enemies'] + 1)
df['election_log'] = np.log(df['election'] + 1)
df['globalism_log'] = np.log(df['globalism'] + 1)
df['biden_campaign_log'] = np.log(df['biden_campaign'] + 1)
# Out:
# total original data points: 224969

# %%
#get rep change variable
df.sort_values(['user_id', 'period'], inplace=True)
df['rep_change'] = df.groupby(['user_id', 'school'])['rep_count'].diff()

#get dem change variable
df.sort_values(['user_id', 'period'], inplace=True)
df['dem_change'] = df.groupby(['user_id', 'school'])['dem_count'].diff()

#individuals that have at least one change
new = df.loc[(df['rep_change'] != 0) | (df['dem_change'] != 0) | (df['num_tweets'] != 0)]

#at least one tweet
new2 = df = df.loc[df['emot_100_mean'] != 0]

print(len(new))
# Out:
# 80355

# %%
#get base models for all 7 schools
for s in schools:
    school = new[new['school'] == s]
    
    school = school.set_index(['user_id', 'period'])
    
    #rep model
    mod = PanelOLS.from_formula('emot_100_mean ~ + log_rep_count + log_dem_count + TimeEffects + EntityEffects', school)
    res = mod.fit(cov_type = 'clustered', cluster_entity = True)
    print('####### ' + s + ' ########')
    print(res)
# Out:
# ####### s1 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0025
# Estimator:                   PanelOLS   R-squared (Between):             -2.1113
# No. Observations:                5108   R-squared (Within):               0.0011
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -1.5147
# Time:                        18:44:19   Log-likelihood                    4868.7
# Cov. Estimator:             Clustered
#                                         F-statistic:                      6.0386
# Entities:                         247   P-value                           0.0024
# Avg Obs:                       20.680   Distribution:                  F(2,4829)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             4.0692
#                                         P-value                           0.0171
# Time periods:                      31   Distribution:                  F(2,4829)
# Avg Obs:                       164.77
# Min Obs:                       112.00
# Max Obs:                       231.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.0304     0.0140     2.1745     0.0297      0.0030      0.0578
# log_dem_count     0.0057     0.0133     0.4279     0.6687     -0.0204      0.0317
# =================================================================================
#
# F-test for Poolability: 18.893
# P-value: 0.0000
# Distribution: F(276,4829)
#
# Included effects: Entity, Time
# ####### s2 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0003
# Estimator:                   PanelOLS   R-squared (Between):             -0.4216
# No. Observations:                3249   R-squared (Within):              -0.0005
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.2753
# Time:                        18:44:19   Log-likelihood                    3335.4
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.4794
# Entities:                         156   P-value                           0.6192
# Avg Obs:                       20.827   Distribution:                  F(2,3061)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             1.6937
#                                         P-value                           0.1840
# Time periods:                      31   Distribution:                  F(2,3061)
# Avg Obs:                       104.81
# Min Obs:                       83.000
# Max Obs:                       154.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.0108     0.0108     1.0001     0.3173     -0.0104      0.0320
# log_dem_count    -0.0040     0.0161    -0.2498     0.8027     -0.0357      0.0276
# =================================================================================
#
# F-test for Poolability: 14.444
# P-value: 0.0000
# Distribution: F(185,3061)
#
# Included effects: Entity, Time
# ####### s3 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0005
# Estimator:                   PanelOLS   R-squared (Between):             -0.1522
# No. Observations:               15463   R-squared (Within):               0.0016
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.1098
# Time:                        18:44:20   Log-likelihood                 2.023e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3.9997
# Entities:                         663   P-value                           0.0183
# Avg Obs:                       23.323   Distribution:                 F(2,14768)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             5.6055
#                                         P-value                           0.0037
# Time periods:                      31   Distribution:                 F(2,14768)
# Avg Obs:                       498.81
# Min Obs:                       373.00
# Max Obs:                       631.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count    -0.0074     0.0066    -1.1149     0.2649     -0.0203      0.0056
# log_dem_count     0.0135     0.0040     3.3440     0.0008      0.0056      0.0214
# =================================================================================
#
# F-test for Poolability: 24.463
# P-value: 0.0000
# Distribution: F(692,14768)
#
# Included effects: Entity, Time
# ####### s4 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0011
# Estimator:                   PanelOLS   R-squared (Between):             -0.1444
# No. Observations:                2960   R-squared (Within):               0.0016
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.1210
# Time:                        18:44:20   Log-likelihood                    3579.7
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.5514
# Entities:                         139   P-value                           0.2121
# Avg Obs:                       21.295   Distribution:                  F(2,2789)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             2.5624
#                                         P-value                           0.0773
# Time periods:                      31   Distribution:                  F(2,2789)
# Avg Obs:                       95.484
# Min Obs:                       82.000
# Max Obs:                       137.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count    -0.0183     0.0151    -1.2049     0.2283     -0.0480      0.0115
# log_dem_count     0.0268     0.0133     2.0120     0.0443      0.0007      0.0530
# =================================================================================
#
# F-test for Poolability: 20.975
# P-value: 0.0000
# Distribution: F(168,2789)
#
# Included effects: Entity, Time
# ####### s5 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0002
# Estimator:                   PanelOLS   R-squared (Between):             -0.1029
# No. Observations:               26752   R-squared (Within):               0.0006
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.0616
# Time:                        18:44:20   Log-likelihood                  3.29e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.9455
# Entities:                        1145   P-value                           0.0526
# Avg Obs:                       23.364   Distribution:                 F(2,25575)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             1.4814
#                                         P-value                           0.2273
# Time periods:                      31   Distribution:                 F(2,25575)
# Avg Obs:                       862.97
# Min Obs:                       699.00
# Max Obs:                       1132.0
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count    -0.0076     0.0091    -0.8441     0.3986     -0.0254      0.0101
# log_dem_count     0.0114     0.0067     1.7139     0.0866     -0.0016      0.0245
# =================================================================================
#
# F-test for Poolability: 18.614
# P-value: 0.0000
# Distribution: F(1174,25575)
#
# Included effects: Entity, Time
# ####### s6 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0015
# Estimator:                   PanelOLS   R-squared (Between):             -2.2416
# No. Observations:                5223   R-squared (Within):               0.0010
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -1.4896
# Time:                        18:44:20   Log-likelihood                    5126.2
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3.7112
# Entities:                         264   P-value                           0.0245
# Avg Obs:                       19.784   Distribution:                  F(2,4927)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             3.4430
#                                         P-value                           0.0320
# Time periods:                      31   Distribution:                  F(2,4927)
# Avg Obs:                       168.48
# Min Obs:                       141.00
# Max Obs:                       257.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.0258     0.0122     2.1227     0.0338      0.0020      0.0497
# log_dem_count     0.0082     0.0139     0.5890     0.5559     -0.0190      0.0354
# =================================================================================
#
# F-test for Poolability: 10.575
# P-value: 0.0000
# Distribution: F(293,4927)
#
# Included effects: Entity, Time
# ####### s8 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0005
# Estimator:                   PanelOLS   R-squared (Between):             -0.7585
# No. Observations:               21600   R-squared (Within):              -0.0001
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.4667
# Time:                        18:44:21   Log-likelihood                 2.469e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      5.0578
# Entities:                        1039   P-value                           0.0064
# Avg Obs:                       20.789   Distribution:                 F(2,20529)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             3.7343
#                                         P-value                           0.0239
# Time periods:                      31   Distribution:                 F(2,20529)
# Avg Obs:                       696.77
# Min Obs:                       514.00
# Max Obs:                       1026.0
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# log_rep_count     0.0077     0.0055     1.4035     0.1605     -0.0030      0.0184
# log_dem_count     0.0103     0.0065     1.5695     0.1165     -0.0026      0.0231
# =================================================================================
#
# F-test for Poolability: 18.195
# P-value: 0.0000
# Distribution: F(1068,20529)
#
# Included effects: Entity, Time

# %%
#get base models for all 7 schools
for s in schools:
    school = new[new['school'] == s]
    
    school = school.set_index(['user_id', 'period'])
    
    #rep model
    mod = PanelOLS.from_formula('emot_100_mean ~ + log_rep_count + log_dem_count + covid_restrictions_log + economics_log + police_violence_log + argument_log + fed_investigation_log + law_constitution_log + racism_log + voting_log + ideology_log + riot_log + covid_log + police_violence_log + derogatory_media_log + foreign_enemies_log + globalism_log + TimeEffects + EntityEffects', school)
    res = mod.fit(cov_type = 'clustered', cluster_entity = True)
    print('####### ' + s + ' ########')
    print(res)
# Out:
# ####### s1 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0137
# Estimator:                   PanelOLS   R-squared (Between):             -2.1885
# No. Observations:                5108   R-squared (Within):               0.0147
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -1.5970
# Time:                        18:44:56   Log-likelihood                    4897.5
# Cov. Estimator:             Clustered
#                                         F-statistic:                      4.1748
# Entities:                         247   P-value                           0.0000
# Avg Obs:                       20.680   Distribution:                 F(16,4815)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             4.0166
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(16,4815)
# Avg Obs:                       164.77
# Min Obs:                       112.00
# Max Obs:                       231.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.0293     0.0136     2.1550     0.0312      0.0026      0.0560
# log_dem_count              0.0053     0.0129     0.4117     0.6806     -0.0201      0.0307
# covid_restrictions_log    -0.0016     0.0027    -0.6076     0.5435     -0.0069      0.0036
# economics_log             -0.0063     0.0029    -2.2068     0.0274     -0.0119     -0.0007
# police_violence_log        0.0020     0.0030     0.6765     0.4988     -0.0038      0.0078
# argument_log               0.0057     0.0027     2.1435     0.0321      0.0005      0.0109
# fed_investigation_log     -0.0069     0.0030    -2.2907     0.0220     -0.0128     -0.0010
# law_constitution_log       0.0070     0.0035     1.9845     0.0473   8.465e-05      0.0139
# racism_log                 0.0069     0.0028     2.5027     0.0124      0.0015      0.0123
# voting_log                 0.0003     0.0027     0.1167     0.9071     -0.0049      0.0056
# ideology_log               0.0013     0.0026     0.4820     0.6298     -0.0039      0.0064
# riot_log                   0.0075     0.0029     2.6125     0.0090      0.0019      0.0131
# covid_log                  0.0011     0.0027     0.4155     0.6778     -0.0042      0.0064
# derogatory_media_log       0.0034     0.0027     1.2669     0.2052     -0.0019      0.0087
# foreign_enemies_log       -0.0031     0.0029    -1.0762     0.2819     -0.0089      0.0026
# globalism_log              0.0113     0.0028     4.0389     0.0001      0.0058      0.0168
# ==========================================================================================
#
# F-test for Poolability: 16.287
# P-value: 0.0000
# Distribution: F(276,4815)
#
# Included effects: Entity, Time
# ####### s2 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0101
# Estimator:                   PanelOLS   R-squared (Between):             -0.4740
# No. Observations:                3249   R-squared (Within):               0.0133
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.3263
# Time:                        18:44:56   Log-likelihood                    3351.3
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.9342
# Entities:                         156   P-value                           0.0140
# Avg Obs:                       20.827   Distribution:                 F(16,3047)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             2.4302
#                                         P-value                           0.0012
# Time periods:                      31   Distribution:                 F(16,3047)
# Avg Obs:                       104.81
# Min Obs:                       83.000
# Max Obs:                       154.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.0081     0.0104     0.7836     0.4333     -0.0122      0.0285
# log_dem_count             -0.0010     0.0154    -0.0666     0.9469     -0.0312      0.0292
# covid_restrictions_log     0.0028     0.0029     0.9372     0.3487     -0.0030      0.0085
# economics_log             -0.0051     0.0032    -1.6051     0.1086     -0.0114      0.0011
# police_violence_log        0.0074     0.0030     2.4661     0.0137      0.0015      0.0133
# argument_log               0.0029     0.0031     0.9321     0.3514     -0.0032      0.0090
# fed_investigation_log     -0.0049     0.0030    -1.6470     0.0997     -0.0108      0.0009
# law_constitution_log       0.0026     0.0032     0.8252     0.4093     -0.0036      0.0089
# racism_log                 0.0053     0.0034     1.5606     0.1187     -0.0014      0.0120
# voting_log                -0.0053     0.0036    -1.4780     0.1395     -0.0124      0.0017
# ideology_log               0.0003     0.0034     0.0934     0.9256     -0.0064      0.0070
# riot_log                   0.0049     0.0035     1.3999     0.1616     -0.0020      0.0117
# covid_log                 -0.0004     0.0030    -0.1455     0.8844     -0.0064      0.0055
# derogatory_media_log       0.0012     0.0032     0.3749     0.7078     -0.0051      0.0075
# foreign_enemies_log       -0.0033     0.0028    -1.1640     0.2445     -0.0088      0.0022
# globalism_log              0.0117     0.0036     3.2186     0.0013      0.0046      0.0188
# ==========================================================================================
#
# F-test for Poolability: 12.091
# P-value: 0.0000
# Distribution: F(185,3047)
#
# Included effects: Entity, Time
# ####### s3 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0121
# Estimator:                   PanelOLS   R-squared (Between):             -0.0512
# No. Observations:               15463   R-squared (Within):               0.0240
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.0264
# Time:                        18:44:56   Log-likelihood                 2.032e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      11.315
# Entities:                         663   P-value                           0.0000
# Avg Obs:                       23.323   Distribution:                F(16,14754)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             16.043
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                F(16,14754)
# Avg Obs:                       498.81
# Min Obs:                       373.00
# Max Obs:                       631.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count             -0.0071     0.0067    -1.0641     0.2873     -0.0203      0.0060
# log_dem_count              0.0119     0.0038     3.0907     0.0020      0.0043      0.0194
# covid_restrictions_log     0.0015     0.0009     1.6481     0.0994     -0.0003      0.0034
# economics_log             -0.0027     0.0010    -2.8270     0.0047     -0.0046     -0.0008
# police_violence_log        0.0017     0.0010     1.7556     0.0792     -0.0002      0.0035
# argument_log               0.0005     0.0011     0.4930     0.6220     -0.0016      0.0026
# fed_investigation_log     -0.0045     0.0009    -4.7105     0.0000     -0.0063     -0.0026
# law_constitution_log       0.0045     0.0011     4.0388     0.0001      0.0023      0.0067
# racism_log                 0.0031     0.0010     3.1164     0.0018      0.0012      0.0051
# voting_log                -0.0079     0.0010    -7.6536     0.0000     -0.0099     -0.0058
# ideology_log              -0.0015     0.0010    -1.4650     0.1430     -0.0035      0.0005
# riot_log                   0.0076     0.0011     7.1438     0.0000      0.0055      0.0096
# covid_log                 -0.0028     0.0009    -3.2941     0.0010     -0.0045     -0.0011
# derogatory_media_log       0.0008     0.0009     0.8686     0.3851     -0.0010      0.0027
# foreign_enemies_log       -0.0013     0.0010    -1.3015     0.1931     -0.0032      0.0006
# globalism_log              0.0084     0.0011     7.8143     0.0000      0.0063      0.0106
# ==========================================================================================
#
# F-test for Poolability: 20.191
# P-value: 0.0000
# Distribution: F(692,14754)
#
# Included effects: Entity, Time
# ####### s4 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0131
# Estimator:                   PanelOLS   R-squared (Between):             -0.0826
# No. Observations:                2960   R-squared (Within):               0.0156
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.0711
# Time:                        18:44:57   Log-likelihood                    3597.6
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.3042
# Entities:                         139   P-value                           0.0023
# Avg Obs:                       21.295   Distribution:                 F(16,2775)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             4.3284
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(16,2775)
# Avg Obs:                       95.484
# Min Obs:                       82.000
# Max Obs:                       137.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count             -0.0196     0.0144    -1.3620     0.1733     -0.0479      0.0086
# log_dem_count              0.0259     0.0132     1.9662     0.0494   7.118e-05      0.0518
# covid_restrictions_log     0.0045     0.0029     1.5231     0.1278     -0.0013      0.0102
# economics_log             -0.0053     0.0031    -1.7261     0.0844     -0.0112      0.0007
# police_violence_log        0.0031     0.0024     1.2719     0.2035     -0.0017      0.0078
# argument_log               0.0014     0.0028     0.5006     0.6167     -0.0041      0.0069
# fed_investigation_log     -0.0057     0.0024    -2.3426     0.0192     -0.0105     -0.0009
# law_constitution_log       0.0078     0.0037     2.1257     0.0336      0.0006      0.0150
# racism_log                 0.0012     0.0027     0.4408     0.6594     -0.0041      0.0064
# voting_log                -0.0119     0.0035    -3.4563     0.0006     -0.0187     -0.0052
# ideology_log               0.0012     0.0032     0.3704     0.7111     -0.0052      0.0076
# riot_log                   0.0072     0.0027     2.6859     0.0073      0.0019      0.0124
# covid_log                 -0.0033     0.0029    -1.1134     0.2656     -0.0090      0.0025
# derogatory_media_log       0.0011     0.0025     0.4581     0.6469     -0.0037      0.0060
# foreign_enemies_log        0.0003     0.0028     0.1200     0.9045     -0.0052      0.0059
# globalism_log              0.0089     0.0030     2.9501     0.0032      0.0030      0.0148
# ==========================================================================================
#
# F-test for Poolability: 17.369
# P-value: 0.0000
# Distribution: F(168,2775)
#
# Included effects: Entity, Time
# ####### s5 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0118
# Estimator:                   PanelOLS   R-squared (Between):             -0.0458
# No. Observations:               26752   R-squared (Within):               0.0181
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.0207
# Time:                        18:44:57   Log-likelihood                 3.305e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      19.022
# Entities:                        1145   P-value                           0.0000
# Avg Obs:                       23.364   Distribution:                F(16,25561)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             26.442
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                F(16,25561)
# Avg Obs:                       862.97
# Min Obs:                       699.00
# Max Obs:                       1132.0
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count             -0.0083     0.0087    -0.9523     0.3410     -0.0254      0.0088
# log_dem_count              0.0109     0.0066     1.6455     0.0999     -0.0021      0.0239
# covid_restrictions_log     0.0006     0.0008     0.8307     0.4062     -0.0009      0.0021
# economics_log             -0.0042     0.0008    -5.4146     0.0000     -0.0057     -0.0027
# police_violence_log        0.0028     0.0008     3.5956     0.0003      0.0013      0.0043
# argument_log              -0.0003     0.0008    -0.3963     0.6919     -0.0019      0.0013
# fed_investigation_log     -0.0045     0.0008    -6.0034     0.0000     -0.0060     -0.0031
# law_constitution_log       0.0061     0.0009     6.4845     0.0000      0.0042      0.0079
# racism_log                 0.0048     0.0008     5.7218     0.0000      0.0032      0.0065
# voting_log                -0.0069     0.0009    -7.7459     0.0000     -0.0087     -0.0052
# ideology_log               0.0006     0.0009     0.6923     0.4888     -0.0011      0.0023
# riot_log                   0.0071     0.0008     8.8017     0.0000      0.0055      0.0087
# covid_log                 -0.0013     0.0008    -1.6253     0.1041     -0.0028      0.0003
# derogatory_media_log       0.0013     0.0008     1.5489     0.1214     -0.0003      0.0029
# foreign_enemies_log       -0.0018     0.0009    -2.0698     0.0385     -0.0034  -9.394e-05
# globalism_log              0.0075     0.0010     7.8378     0.0000      0.0056      0.0094
# ==========================================================================================
#
# F-test for Poolability: 16.468
# P-value: 0.0000
# Distribution: F(1174,25561)
#
# Included effects: Entity, Time
# ####### s6 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0127
# Estimator:                   PanelOLS   R-squared (Between):             -2.2161
# No. Observations:                5223   R-squared (Within):               0.0129
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -1.5034
# Time:                        18:44:57   Log-likelihood                    5155.6
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3.9394
# Entities:                         264   P-value                           0.0000
# Avg Obs:                       19.784   Distribution:                 F(16,4913)
# Min Obs:                       2.0000
# Max Obs:                       31.000   F-statistic (robust):             5.7581
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                 F(16,4913)
# Avg Obs:                       168.48
# Min Obs:                       141.00
# Max Obs:                       257.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.0252     0.0115     2.1872     0.0288      0.0026      0.0479
# log_dem_count              0.0066     0.0132     0.4975     0.6188     -0.0193      0.0324
# covid_restrictions_log     0.0021     0.0027     0.7747     0.4386     -0.0032      0.0074
# economics_log              0.0006     0.0027     0.2058     0.8369     -0.0047      0.0058
# police_violence_log        0.0018     0.0032     0.5812     0.5611     -0.0043      0.0080
# argument_log               0.0084     0.0030     2.8332     0.0046      0.0026      0.0143
# fed_investigation_log     -0.0029     0.0033    -0.8833     0.3771     -0.0093      0.0035
# law_constitution_log      -0.0011     0.0029    -0.3672     0.7135     -0.0068      0.0047
# racism_log                -0.0019     0.0036    -0.5438     0.5866     -0.0089      0.0050
# voting_log                -0.0085     0.0029    -2.9433     0.0033     -0.0141     -0.0028
# ideology_log               0.0055     0.0033     1.7046     0.0883     -0.0008      0.0119
# riot_log                   0.0092     0.0030     3.0643     0.0022      0.0033      0.0151
# covid_log                 -0.0035     0.0028    -1.2378     0.2159     -0.0091      0.0021
# derogatory_media_log      -0.0040     0.0027    -1.4635     0.1434     -0.0093      0.0013
# foreign_enemies_log       -0.0069     0.0030    -2.2705     0.0232     -0.0129     -0.0009
# globalism_log              0.0211     0.0032     6.7037     0.0000      0.0149      0.0273
# ==========================================================================================
#
# F-test for Poolability: 9.7127
# P-value: 0.0000
# Distribution: F(293,4913)
#
# Included effects: Entity, Time
# ####### s8 ########
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          emot_100_mean   R-squared:                        0.0108
# Estimator:                   PanelOLS   R-squared (Between):             -0.7755
# No. Observations:               21600   R-squared (Within):               0.0146
# Date:                Fri, Apr 16 2021   R-squared (Overall):             -0.4984
# Time:                        18:44:58   Log-likelihood                  2.48e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      13.968
# Entities:                        1039   P-value                           0.0000
# Avg Obs:                       20.789   Distribution:                F(16,20515)
# Min Obs:                       1.0000
# Max Obs:                       31.000   F-statistic (robust):             18.182
#                                         P-value                           0.0000
# Time periods:                      31   Distribution:                F(16,20515)
# Avg Obs:                       696.77
# Min Obs:                       514.00
# Max Obs:                       1026.0
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# log_rep_count              0.0064     0.0057     1.1162     0.2643     -0.0048      0.0176
# log_dem_count              0.0104     0.0067     1.5504     0.1210     -0.0027      0.0236
# covid_restrictions_log     0.0005     0.0010     0.4977     0.6187     -0.0015      0.0026
# economics_log             -0.0033     0.0010    -3.3417     0.0008     -0.0052     -0.0013
# police_violence_log        0.0009     0.0010     0.8169     0.4140     -0.0012      0.0029
# argument_log               0.0032     0.0011     2.7984     0.0051      0.0010      0.0054
# fed_investigation_log     -0.0046     0.0010    -4.7652     0.0000     -0.0065     -0.0027
# law_constitution_log       0.0055     0.0013     4.2734     0.0000      0.0030      0.0080
# racism_log                 0.0058     0.0011     5.3295     0.0000      0.0037      0.0080
# voting_log                -0.0078     0.0011    -6.8224     0.0000     -0.0100     -0.0056
# ideology_log              -0.0010     0.0011    -0.9388     0.3478     -0.0031      0.0011
# riot_log                   0.0062     0.0012     5.2938     0.0000      0.0039      0.0084
# covid_log                 -0.0022     0.0010    -2.2167     0.0267     -0.0041     -0.0003
# derogatory_media_log       0.0028     0.0010     2.7795     0.0054      0.0008      0.0048
# foreign_enemies_log       -0.0033     0.0010    -3.1563     0.0016     -0.0053     -0.0012
# globalism_log              0.0097     0.0012     8.4356     0.0000      0.0075      0.0120
# ==========================================================================================
#
# F-test for Poolability: 16.324
# P-value: 0.0000
# Distribution: F(1068,20515)
#
# Included effects: Entity, Time
