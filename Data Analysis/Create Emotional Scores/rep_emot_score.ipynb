# %%
#rep script for attaching negative valence scores to tweets
import pandas as pd
import numpy as np
from gensim.models import Word2Vec
from numpy import dot
from numpy.linalg import norm

INPUT = '/home/twalton_umass_edu/Political Polarization Project/tmls/word_embeddings/sent_embed/'
OUPUT = '/home/twalton_umass_edu/Political Polarization Project/tmls/word_embeddings/sent_embed/final/'

num_words = [50, 100, 150, 200]

# %%
#cosine similarity function
def cosine_sim(a, b):
    return dot(a, b) / (norm(a)*norm(b))

# %%
for i in range(8):
    #load cleaned text dataframe
    text = pd.read_csv(INPUT + 'cleaned/rep_clean_' + str(i) + '.csv')
    #load sentence embeddings
    embedding = pd.read_csv(INPUT + 'trained/rep_trained_' + str(i) + '.csv')
    
    print('length of text: ' + str(len(text)))
    print('length of embedding: ' + str(len(text)))
    
    #remove unnamed axxis from embedding
    embedding = embedding.drop(['Unnamed: 0'], axis = 1)
    
    for num in num_words:
        neg = np.load('/home/twalton_umass_edu/Political Polarization Project/tmls/word_embeddings/emotions/rep_neg_dimension_' + str(num) + '.npy')
        #vector for holding scores
        scores = []
    
        #loop through and calculate cosine similarity
        for tweet in range(len(text)):
            score = cosine_sim(embedding.loc[tweet], neg)
            scores.append(score)
            if tweet % 100000 == 0:
                print(tweet)
    
        #create new variable
        text['neg_emot_score_' + str(num)] = scores
    
    #save output
    text.to_csv(OUPUT + 'rep_final_' + str(i) + '.csv')
    
    print(i)
# Out:
# length of text: 2406714
# length of embedding: 2406714
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# ...
